# %% [markdown]
# # Data Science project template

# %% [markdown]
# ### Basic imports, the rest will be imported on the way

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn as skl

# %matplotlib inline

# %% [markdown]
# ### Couple of questions to bare in mind
# ***
# 1. What is the project objective?
# 2. How the solution will be used?
# 3. supervised/unsupervised?
# 4. How can me measure the performance of the solution?
# 5. What is the minimum performance needed to accteptance?
# 6. How can you solve problem manually?
# 7. Are there any assumptions or clues known before?

# %% [markdown]
# ## Get the data

# %% [markdown]
# ### Check list
# ***
# 1. List the data you need and how much
# 2. Find data source
# 3. How much space it will take?
# 4. Check the legal oblicgations(get authorization if necessary and possible)
# 5. Convert data to format you can easly manipulate
# 6. Ensure the sensitive data is deleted
# 7. Sample test set and put it aside <-- if applicable

# %%
from sklearn.model_selection import train_test_split

#Lets assume for now that data is in csv file

data_file = 'test_data/train.csv'
# train_file = ''
# test_file = ''

data = pd.read_csv(data_file)
# train = pd.read_csv(train_file)
# test = pd.read_csv(test_file)

# You don't need train test split if you are going to use cross validation while training a model
# train, test = train_test_split(data, train_size=0.8, test_size=0.2, random_state=0)

# %% [markdown]
# ## Data exploration

# %% [markdown]
# Check list
# ***
#
# 1. Study each attribute and its characteristics:Name, Type, % of missing values, Noisiness and type of noise (stochastic, outliers, rounding errors, etc.), Usefulness for the task, Type of distribution (Gaussian, uniform, logarithmic, etc.)
#
# 2. For supervised learning tasks, identify the target attribute(s).
#
# 3. Visualize the data.
#
# 4. Study the correlations between attributes.
#
# 5. Identify the promising transformations you may want to apply.
#
# 6. Identify extra data that would be useful (go back to “Get the Data”).
#
# 7. Document what you have learned.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
target_column = 'Survived'
# y = data[target_column]
# data.drop(target_column, axis=1, inplace=True)

categorical_cols = data.loc[:,data.dtypes == "object"].columns
numerical_cols = data.loc[:,data.dtypes != "object"].columns

# %%
axes = []
cols = categorical_cols
num_of_cols = len(cols)
fig = plt.figure(figsize=(12, 12 * num_of_cols))

for i in range(num_of_cols):    
    plot = data[cols[i]].value_counts()
    
    if len(plot) > 10:
        continue
    
    
    ax = fig.add_subplot(num_of_cols, 1, i + 1)
    axes.append(ax)
    
    plot.plot(kind='bar', ax=ax, label=cols[i])
    ax.legend()

# %%
_= sns.pairplot(data, hue=target_column, height=2.5)
# Out:
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/statsmodels/nonparametric/kde.py:488: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/statsmodels/nonparametric/kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/statsmodels/nonparametric/kde.py:448: RuntimeWarning: invalid value encountered in greater
#   X = X[np.logical_and(X > clip[0], X < clip[1])] # won't work for two columns.
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/statsmodels/nonparametric/kde.py:448: RuntimeWarning: invalid value encountered in less
#   X = X[np.logical_and(X > clip[0], X < clip[1])] # won't work for two columns.

# %% [markdown]
# ### Here is a place for your custom visualizations

# %%
categorical_cols
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %%
# example
sns.catplot(data=data, kind="swarm", x="Pclass", y="Age", hue="Survived")
# As we can see the first class passengers have better change of surviving

# %%
sns.catplot(data=data, kind="swarm", x="Sex", y="Age", hue="Survived")
# As we could expect there was a bigger chance of surviving if you were a women, age seems to be significant factor too

# %%
sns.catplot(data=data, kind="swarm", x="Embarked", y="Age", hue="Survived")
# There is no clear corellation wether the place of embark has a significant impact

# %% [markdown]
# ### Let's see what are a various corellations between variables

# %%
ax = plt.figure(figsize=(12, 12)).add_subplot(1, 1, 1)
sns.heatmap(data.corr(), annot=True,ax=ax)

# %%
# There is one more thing I would like to visualize before going further
# The cabin/survived relationship. We need to clean cabin column first
# While training we will try two solutions, one with seperate value for Unk, second one adjusted based on knn
data['transformed_cabin'] = data['Cabin'].fillna('N').map(lambda x: x[0])
data.loc[data['transformed_cabin'] == 'T', "transformed_cabin"] = 'N'
sns.catplot(data=data, kind="swarm", x="transformed_cabin", y="Age", hue="Survived")

# %% [markdown]
# ## Prepare the Data

# %% [markdown]
# ### Check list
# ***
# 1. Data cleaning:
#     * Fix or remove outliers (optional)
#     * Fill in missing values (e.g., with zero, mean, median…) or drop their rows (or columns).
#     * Feature selection (optional):
# 	* Drop the attributes that provide no useful information for the task.
# 2. Feature engineering, where appropriate:
#     * Discretize continuous features.
# 	* Decompose features (e.g., categorical, date/time, etc.).
# 	* Add promising transformations of features (e.g., log(x), sqrt(x), x2, etc.).
# 	* Aggregate features into promising new features.
# 3. Feature scaling:
#     * Standardize or normalize features.

# %%
# Let's see on null values once again
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 13 columns):
# PassengerId          891 non-null int64
# Survived             891 non-null int64
# Pclass               891 non-null int64
# Name                 891 non-null object
# Sex                  891 non-null object
# Age                  714 non-null float64
# SibSp                891 non-null int64
# Parch                891 non-null int64
# Ticket               891 non-null object
# Fare                 891 non-null float64
# Cabin                204 non-null object
# Embarked             889 non-null object
# transformed_cabin    891 non-null object
# dtypes: float64(2), int64(5), object(6)
# memory usage: 90.6+ KB

# %%
y = data[target_column]

# you can get rid of columns which will be useless for sure in predictions such us id etc.
cols_to_drop=["PassengerId", "Name", "Cabin","Ticket", "transformed_cabin"] + [target_column]
data.drop(cols_to_drop, axis=1, inplace=True)

categorical_cols = data.loc[:,data.dtypes == "object"].columns
numerical_cols = data.loc[:,data.dtypes != "object"].columns

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler, OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer

num_pipeline = Pipeline([
        ('imputer', SimpleImputer(strategy='mean')),
        ('std_scaler', StandardScaler())
    ])

cat_pipeline = Pipeline([
        ('imputer', SimpleImputer(strategy='most_frequent')),#, fill_value='None')),
        ('one_hot', OneHotEncoder(handle_unknown='ignore'))
    ])

full_pipeline = ColumnTransformer([
        ('num', num_pipeline, numerical_cols),
        ('cat', cat_pipeline, categorical_cols)
    ])
    

data = full_pipeline.fit_transform(data, y)

# %% [markdown]
# ### Shortlist Promising Models
#
# #### If the data is huge, you may want to sample smaller training sets so you can train many different models in a reasonable time (be aware that this penalizes complex models such as large neural nets or Random Forests).

# %% [markdown]
# ### Check list
#
# 1. Once again, try to automate these steps as much as possible.
#
# 2. Train many quick-and-dirty models from different categories (e.g., linear, naive Bayes, SVM, Random Forest, neural net, etc.) using standard parameters.
#
# 3. Measure and compare their performance.
#     * For each model, use N-fold cross-validation and compute the mean and standard deviation of the performance measure on the N folds.
#
# 4. Analyze the most significant variables for each algorithm.
#
# 5. Analyze the types of errors the models make.
#     * What data would a human have used to avoid these errors?
#
# 6. Perform a quick round of feature selection and engineering.
#
# 7. Perform one or two more quick iterations of the five previous steps.
#
# #### Shortlist the top three to five most promising models, preferring models that make different types of errors.(Crete tool to show falsy predictions)

# %% [markdown]
# ### If you do not know what model to choose, you can use map from sklear documentation

# %% [markdown]
# <img src="../resources/ml_map.png" alt="ml map"/>

# %% [markdown]
# ### Keep in mind that it does not contain boost models which usually perform the best
# #### You can see some of them here
#     * XGBoost
#     * LightGBM
#     * CatBoost
#     * GBM

# %%
# To resolve our titanic problem we need categorical classyficator
# Let's import models which I will use
from sklearn.ensemble import AdaBoostClassifier, RandomForestClassifier
from sklearn.linear_model import LogisticRegressionCV
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import LinearSVC, SVC
from xgboost.sklearn import XGBClassifier
from lightgbm.sklearn import LGBMClassifier

from scipy.stats import uniform
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import cross_validate

from random import randint
# Out:
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/dask/config.py:168: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   data = yaml.load(f.read()) or {}
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/distributed/config.py:20: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   defaults = yaml.load(f)

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, roc_curve, precision_recall_curve, auc, make_scorer, confusion_matrix, f1_score, fbeta_score
scoring = {'AUC': 'roc_auc', 'Accuracy': make_scorer(accuracy_score)}

# %%
parameters = {
    "n_estimators": list(range(20, 200)),
    "learning_rate": uniform(0.001, 0.199),
    "num_leaves": list(range(2, 100)),
    "bagging_freq": list(range(1, 5)),
    "max_bin": list(range(1, 200)),
    "lambda_l1": uniform(0.001, 0.199),
    "lambda_l2": uniform(0.001, 0.199),
    } 

model = LGBMClassifier(extra_trees=True)
randomsearch = RandomizedSearchCV(model,
                                  param_distributions=parameters,
                                  n_iter=500,
                                  cv=4,
                                  random_state=1,
                                  scoring=scoring,
                                  return_train_score=True,
                                  refit='Accuracy',
                                  )

r = randomsearch.fit(data,y)
# Out:
# [LightGBM] [Warning] lambda_l1 is set=0.19943977737683485, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.19943977737683485
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] lambda_l2 is set=0.18657891450839312, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.18657891450839312
# [LightGBM] [Warning] lambda_l1 is set=0.19943977737683485, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.19943977737683485
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] lambda_l2 is set=0.18657891450839312, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.18657891450839312
# [LightGBM] [Warning] lambda_l1 is set=0.19943977737683485, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.19943977737683485
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] lambda_l2 is set=0.18657891450839312, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.18657891450839312
# [LightGBM] [Warning] lambda_l1 is set=0.19943977737683485, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.19943977737683485
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] lambda_l2 is set=0.18657891450839312, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.18657891450839312
# [LightGBM] [Warning] lambda_l1 is set=0.0799195647319092, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.0799195647319092
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] lambda_l2 is set=0.07819423749123948, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.07819423749123948
# [LightGBM] [Warning] lambda_l1 is set=0.0799195647319092, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.0799195647319092
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] lambda_l2 is set=0.07819423749123948, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.07819423749123948
# [LightGBM] [Warning] lambda_l1 is set=0.0799195647319092, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.0799195647319092
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] lambda_l2 is set=0.07819423749123948, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.07819423749123948
# [LightGBM] [Warning] lambda_l1 is set=0.0799195647319092, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.0799195647319092
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] lambda_l2 is set=0.07819423749123948, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.07819423749123948
# [LightGBM] [Warning] lambda_l1 is set=0.06334142986952275, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.06334142986952275
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# [LightGBM] [Warning] lambda_l2 is set=0.10538508375500141, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.10538508375500141
# [LightGBM] [Warning] lambda_l1 is set=0.06334142986952275, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.06334142986952275
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# [LightGBM] [Warning] lambda_l2 is set=0.10538508375500141, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.10538508375500141
# [LightGBM] [Warning] lambda_l1 is set=0.06334142986952275, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.06334142986952275
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# [LightGBM] [Warning] lambda_l2 is set=0.10538508375500141, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.10538508375500141
# [LightGBM] [Warning] lambda_l1 is set=0.06334142986952275, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.06334142986952275
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# [LightGBM] [Warning] lambda_l2 is set=0.10538508375500141, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.10538508375500141
# [LightGBM] [Warning] lambda_l1 is set=0.18287844289126737, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.18287844289126737
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# [LightGBM] [Warning] lambda_l2 is set=0.09198375678941068, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.09198375678941068
# [LightGBM] [Warning] lambda_l1 is set=0.18287844289126737, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.18287844289126737
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# [LightGBM] [Warning] lambda_l2 is set=0.09198375678941068, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.09198375678941068
# [LightGBM] [Warning] lambda_l1 is set=0.18287844289126737, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.18287844289126737
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# [LightGBM] [Warning] lambda_l2 is set=0.09198375678941068, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.09198375678941068
# [LightGBM] [Warning] lambda_l1 is set=0.18287844289126737, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.18287844289126737
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# [LightGBM] [Warning] lambda_l2 is set=0.09198375678941068, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.05845484870841638
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] lambda_l2 is set=0.04711993443974533, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.04711993443974533
# [LightGBM] [Warning] lambda_l1 is set=0.01921973189388286, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.01921973189388286
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# [LightGBM] [Warning] lambda_l2 is set=0.11444326542280282, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.11444326542280282
# [LightGBM] [Warning] lambda_l1 is set=0.01921973189388286, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.01921973189388286
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# [LightGBM] [Warning] lambda_l2 is set=0.11444326542280282, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.11444326542280282
# [LightGBM] [Warning] lambda_l1 is set=0.01921973189388286, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.01921973189388286
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# [LightGBM] [Warning] lambda_l2 is set=0.11444326542280282, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.11444326542280282
# [LightGBM] [Warning] lambda_l1 is set=0.01921973189388286, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.01921973189388286
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# [LightGBM] [Warning] lambda_l2 is set=0.11444326542280282, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.11444326542280282
# [LightGBM] [Warning] lambda_l1 is set=0.05866224054516762, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.05866224054516762
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# [LightGBM] [Warning] lambda_l2 is set=0.14376092865030418, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.14376092865030418
# [LightGBM] [Warning] lambda_l1 is set=0.05866224054516762, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.05866224054516762
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# [LightGBM] [Warning] lambda_l2 is set=0.14376092865030418, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.14376092865030418
# [LightGBM] [Warning] lambda_l1 is set=0.05866224054516762, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.05866224054516762
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# [LightGBM] [Warning] lambda_l2 is set=0.14376092865030418, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.14376092865030418
# [LightGBM] [Warning] lambda_l1 is set=0.05866224054516762, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.05866224054516762
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# [LightGBM] [Warning] lambda_l2 is set=0.14376092865030418, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.14376092865030418
# [LightGBM] [Warning] lambda_l1 is set=0.08613471388587211, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.08613471388587211
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] lambda_l2 is set=0.08624809862788461, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.08624809862788461
# [LightGBM] [Warning] lambda_l1 is set=0.08613471388587211, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.08613471388587211
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] lambda_l2 is set=0.08624809862788461, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.08624809862788461
# [LightGBM] [Warning] lambda_l1 is set=0.08613471388587211, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.08613471388587211
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] lambda_l2 is set=0.08624809862788461, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.08624809862788461
# [LightGBM] [Warning] lambda_l1 is set=0.08613471388587211, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.08613471388587211
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] lambda_l2 is set=0.08624809862788461, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.08624809862788461
# [LightGBM] [Warning] lambda_l1 is set=0.04591615838296309, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.04591615838296309
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] lambda_l2 is set=0.14288480709615267, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.14288480709615267
# [LightGBM] [Warning] lambda_l1 is set=0.04591615838296309, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.04591615838296309
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] lambda_l2 is set=0.14288480709615267, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.14288480709615267
# [LightGBM] [Warning] lambda_l1 is set=0.04591615838296309, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.04591615838296309
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] lambda_l2 is set=0.14288480709615267, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.14288480709615267
# [LightGBM] [Warning] lambda_l1 is set=0.04591615838296309, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.04591615838296309
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] lambda_l2 is set=0.14288480709615267, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.14288480709615267
# [LightGBM] [Warning] lambda_l1 is set=0.05565438509326692, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.05565438509326692
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] lambda_l2 is set=0.01571982970992344, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.01571982970992344
# [LightGBM] [Warning] lambda_l1 is set=0.05565438509326692, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.05565438509326692
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] lambda_l2 is set=0.01571982970992344, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.01571982970992344
# [LightGBM] [Warning] lambda_l1 is set=0.05565438509326692, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.05565438509326692
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] lambda_l2 is set=0.01571982970992344, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.01571982970992344
# [LightGBM] [Warning] lambda_l1 is set=0.05565438509326692, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.05565438509326692
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] lambda_l2 is set=0.01571982970992344, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.01571982970992344
# [LightGBM] [Warning] lambda_l1 is set=0.010953599091760285, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.010953599091760285
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# [LightGBM] [Warning] lambda_l2 is set=0.14845015559144098, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.14845015559144098
# [LightGBM] [Warning] lambda_l1 is set=0.010953599091760285, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.010953599091760285
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# [LightGBM] [Warning] lambda_l2 is set=0.14845015559144098, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.14845015559144098
# [LightGBM] [Warning] lambda_l1 is set=0.010953599091760285, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.010953599091760285
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# [LightGBM] [Warning] lambda_l2 is set=0.14845015559144098, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.14845015559144098
# [LightGBM] [Warning] lambda_l1 is set=0.010953599091760285, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.010953599091760285
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# [LightGBM] [Warning] lambda_l2 is set=0.14845015559144098, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.14845015559144098
# [LightGBM] [Warning] lambda_l1 is set=0.03220148753457077, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.03220148753457077
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# [LightGBM] [Warning] lambda_l2 is set=0.004696664233304494, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.004696664233304494
# [LightGBM] [Warning] lambda_l1 is set=0.03220148753457077, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.03220148753457077
# [LightGBM] [Warning] bagging_freq is set=4, subsample_freq=0 will be ignored. Current value: bagging_freq=4
# [LightGBM] [Warning] lambda_l2 is set=0.004696664233304494, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] lambda_l2 is set=0.10366881836470933, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.10366881836470933
# [LightGBM] [Warning] lambda_l1 is set=0.1314124173045438, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.1314124173045438
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] lambda_l2 is set=0.10366881836470933, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.10366881836470933
# [LightGBM] [Warning] lambda_l1 is set=0.1314124173045438, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.1314124173045438
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] lambda_l2 is set=0.10366881836470933, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.10366881836470933
# [LightGBM] [Warning] lambda_l1 is set=0.1314124173045438, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.1314124173045438
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] lambda_l2 is set=0.10366881836470933, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.10366881836470933
# [LightGBM] [Warning] lambda_l1 is set=0.06968333035396525, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.06968333035396525
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# [LightGBM] [Warning] lambda_l2 is set=0.0266206417690672, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.0266206417690672
# [LightGBM] [Warning] lambda_l1 is set=0.06968333035396525, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.06968333035396525
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# [LightGBM] [Warning] lambda_l2 is set=0.0266206417690672, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.0266206417690672
# [LightGBM] [Warning] lambda_l1 is set=0.06968333035396525, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.06968333035396525
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# [LightGBM] [Warning] lambda_l2 is set=0.0266206417690672, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.0266206417690672
# [LightGBM] [Warning] lambda_l1 is set=0.06968333035396525, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.06968333035396525
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# [LightGBM] [Warning] lambda_l2 is set=0.0266206417690672, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.0266206417690672
# [LightGBM] [Warning] lambda_l1 is set=0.10954237877901908, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.10954237877901908
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] lambda_l2 is set=0.13681313778029094, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.13681313778029094
# [LightGBM] [Warning] lambda_l1 is set=0.10954237877901908, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.10954237877901908
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] lambda_l2 is set=0.13681313778029094, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.13681313778029094
# [LightGBM] [Warning] lambda_l1 is set=0.10954237877901908, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.10954237877901908
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] lambda_l2 is set=0.13681313778029094, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.13681313778029094
# [LightGBM] [Warning] lambda_l1 is set=0.10954237877901908, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.10954237877901908
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] lambda_l2 is set=0.13681313778029094, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.13681313778029094
# [LightGBM] [Warning] lambda_l1 is set=0.06550809933306576, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.06550809933306576
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] lambda_l2 is set=0.008037021978771477, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.008037021978771477
# [LightGBM] [Warning] lambda_l1 is set=0.06550809933306576, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.06550809933306576
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] lambda_l2 is set=0.008037021978771477, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.008037021978771477
# [LightGBM] [Warning] lambda_l1 is set=0.06550809933306576, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.06550809933306576
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] lambda_l2 is set=0.008037021978771477, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.008037021978771477
# [LightGBM] [Warning] lambda_l1 is set=0.06550809933306576, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.06550809933306576
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] lambda_l2 is set=0.008037021978771477, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.008037021978771477
# [LightGBM] [Warning] lambda_l1 is set=0.178170700417624, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.178170700417624
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] lambda_l2 is set=0.0814983616160912, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.0814983616160912
# [LightGBM] [Warning] lambda_l1 is set=0.178170700417624, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.178170700417624
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] lambda_l2 is set=0.0814983616160912, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.0814983616160912
# [LightGBM] [Warning] lambda_l1 is set=0.178170700417624, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.178170700417624
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] lambda_l2 is set=0.0814983616160912, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.0814983616160912
# [LightGBM] [Warning] lambda_l1 is set=0.178170700417624, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.178170700417624
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# [LightGBM] [Warning] lambda_l2 is set=0.0814983616160912, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.0814983616160912
# [LightGBM] [Warning] lambda_l1 is set=0.09464698802027825, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0.09464698802027825
# [LightGBM] [Warning] bagging_freq is set=3, subsample_freq=0 will be ignored. Current value: bagging_freq=3
# [LightGBM] [Warning] lambda_l2 is set=0.19732798313778943, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0.19732798313778943

# %%
scores = r.cv_results_
max(r.cv_results_['mean_test_AUC'])
# Out:
# 0.873517810469255

# %%
lgbm_best = r.best_estimator_

# %%
for mean_score, params in sorted(list(zip(scores["mean_test_AUC"], scores["params"])),key = lambda x: x[0]):
    print(mean_score, params)
# Out:
# 0.7787684146614259 {'bagging_freq': 1, 'learning_rate': 0.004958668084988754, 'max_bin': 170, 'n_estimators': 108, 'num_leaves': 2}
# 0.8363851340555396 {'bagging_freq': 1, 'learning_rate': 0.07401328714001047, 'max_bin': 119, 'n_estimators': 25, 'num_leaves': 2}
# 0.8373518039178092 {'bagging_freq': 3, 'learning_rate': 0.002122748829880584, 'max_bin': 158, 'n_estimators': 165, 'num_leaves': 12}
# 0.8409468571245966 {'bagging_freq': 2, 'learning_rate': 0.0056520495724465, 'max_bin': 127, 'n_estimators': 50, 'num_leaves': 71}
# 0.8417138018087114 {'bagging_freq': 8, 'learning_rate': 0.008886086199511974, 'max_bin': 140, 'n_estimators': 57, 'num_leaves': 88}
# 0.842153197200652 {'bagging_freq': 7, 'learning_rate': 0.026618746851906617, 'max_bin': 198, 'n_estimators': 22, 'num_leaves': 94}
# 0.8423449333716806 {'bagging_freq': 6, 'learning_rate': 0.009024284393992093, 'max_bin': 65, 'n_estimators': 67, 'num_leaves': 72}
# 0.8423928674144378 {'bagging_freq': 3, 'learning_rate': 0.008019393926379088, 'max_bin': 72, 'n_estimators': 104, 'num_leaves': 59}
# 0.8430959000415428 {'bagging_freq': 1, 'learning_rate': 0.006850837106176916, 'max_bin': 77, 'n_estimators': 104, 'num_leaves': 6}
# 0.8432476911769407 {'bagging_freq': 4, 'learning_rate': 0.009606337604457265, 'max_bin': 79, 'n_estimators': 97, 'num_leaves': 68}
# 0.8437190425973861 {'bagging_freq': 3, 'learning_rate': 0.012824487097746494, 'max_bin': 77, 'n_estimators': 74, 'num_leaves': 24}
# 0.8438708337327838 {'bagging_freq': 8, 'learning_rate': 0.1321874307393467, 'max_bin': 49, 'n_estimators': 151, 'num_leaves': 31}
# 0.8439267567826672 {'bagging_freq': 5, 'learning_rate': 0.015517233487041402, 'max_bin': 196, 'n_estimators': 45, 'num_leaves': 15}
# 0.8444859872815006 {'bagging_freq': 7, 'learning_rate': 0.19284248294711792, 'max_bin': 77, 'n_estimators': 181, 'num_leaves': 60}
# 0.8445099543028793 {'bagging_freq': 3, 'learning_rate': 0.17465280944569325, 'max_bin': 57, 'n_estimators': 146, 'num_leaves': 64}
# 0.8446138113955197 {'bagging_freq': 1, 'learning_rate': 0.031631870409318516, 'max_bin': 53, 'n_estimators': 21, 'num_leaves': 16}
# 0.8448135365736748 {'bagging_freq': 5, 'learning_rate': 0.1822638989899015, 'max_bin': 79, 'n_estimators': 187, 'num_leaves': 67}
# 0.845364778065382 {'bagging_freq': 6, 'learning_rate': 0.0033463665357144406, 'max_bin': 21, 'n_estimators': 126, 'num_leaves': 34}
# 0.8453807560796343 {'bagging_freq': 5, 'learning_rate': 0.1800731487066222, 'max_bin': 146, 'n_estimators': 179, 'num_leaves': 43}
# 0.8454366791295178 {'bagging_freq': 1, 'learning_rate': 0.16264826377585276, 'max_bin': 69, 'n_estimators': 178, 'num_leaves': 93}
# 0.8457083053718083 {'bagging_freq': 7, 'learning_rate': 0.1828700678057878, 'max_bin': 20, 'n_estimators': 97, 'num_leaves': 37}
# 0.8458041734573227 {'bagging_freq': 9, 'learning_rate': 0.1944579116259494, 'max_bin': 152, 'n_estimators': 197, 'num_leaves': 83}
# 0.8461237337423705 {'bagging_freq': 2, 'learning_rate': 0.17525867324914657, 'max_bin': 115, 'n_estimators': 195, 'num_leaves': 39}
# 0.8461636787780015 {'bagging_freq': 1, 'learning_rate': 0.014121333034275117, 'max_bin': 16, 'n_estimators': 39, 'num_leaves': 62}
# 0.8462915028920206 {'bagging_freq': 2, 'learning_rate': 0.17730637819401168, 'max_bin': 196, 'n_estimators': 167, 'num_leaves': 91}
# 0.8463953599846612 {'bagging_freq': 5, 'learning_rate': 0.15710850859523687, 'max_bin': 165, 'n_estimators': 192, 'num_leaves': 76}
# 0.8468107883552232 {'bagging_freq': 4, 'learning_rate': 0.1788963014307955, 'max_bin': 35, 'n_estimators': 189, 'num_leaves': 86}
# 0.8472102387115331 {'bagging_freq': 9, 'learning_rate': 0.19175940009989503, 'max_bin': 107, 'n_estimators': 170, 'num_leaves': 58}
# 0.8472421947400377 {'bagging_freq': 3, 'learning_rate': 0.16586218580422896, 'max_bin': 154, 'n_estimators': 153, 'num_leaves': 37}
# 0.8472741507685425 {'bagging_freq': 1, 'learning_rate': 0.19830550595722266, 'max_bin': 182, 'n_estimators': 83, 'num_leaves': 53}
# 0.847338062825552 {'bagging_freq': 4, 'learning_rate': 0.18354713998611144, 'max_bin': 170, 'n_estimators': 160, 'num_leaves': 80}
# 0.8475697440322117 {'bagging_freq': 5, 'learning_rate': 0.17904601565534076, 'max_bin': 186, 'n_estimators': 111, 'num_leaves': 59}
# 0.8477215351676094 {'bagging_freq': 1, 'learning_rate': 0.15520517478698942, 'max_bin': 22, 'n_estimators': 154, 'num_leaves': 36}
# 0.8477455021889879 {'bagging_freq': 6, 'learning_rate': 0.1859761100434512, 'max_bin': 193, 'n_estimators': 132, 'num_leaves': 63}
# 0.8478413702745022 {'bagging_freq': 9, 'learning_rate': 0.19434380675233498, 'max_bin': 191, 'n_estimators': 91, 'num_leaves': 79}
# 0.8480171284312785 {'bagging_freq': 7, 'learning_rate': 0.19184254785537627, 'max_bin': 187, 'n_estimators': 97, 'num_leaves': 30}
# 0.8480251174384049 {'bagging_freq': 9, 'learning_rate': 0.16275308048257756, 'max_bin': 95, 'n_estimators': 178, 'num_leaves': 94}
# 0.848081040488288 {'bagging_freq': 9, 'learning_rate': 0.19869341938014023, 'max_bin': 11, 'n_estimators': 50, 'num_leaves': 83}
# 0.8481209855239192 {'bagging_freq': 5, 'learning_rate': 0.17507155061986843, 'max_bin': 165, 'n_estimators': 164, 'num_leaves': 61}
# 0.8484725018374717 {'bagging_freq': 5, 'learning_rate': 0.015466981491802746, 'max_bin': 184, 'n_estimators': 71, 'num_leaves': 29}
# 0.8486562490013742 {'bagging_freq': 4, 'learning_rate': 0.009922491203703636, 'max_bin': 41, 'n_estimators': 99, 'num_leaves': 38}
# 0.8486642380085002 {'bagging_freq': 4, 'learning_rate': 0.15951005370489904, 'max_bin': 134, 'n_estimators': 183, 'num_leaves': 81}
# 0.8486802160227527 {'bagging_freq': 6, 'learning_rate': 0.1466971678840213, 'max_bin': 59, 'n_estimators': 136, 'num_leaves': 99}
# 0.8487041830441313 {'bagging_freq': 6, 'learning_rate': 0.1550539754136366, 'max_bin': 186, 'n_estimators': 138, 'num_leaves': 54}
# 0.8487840731153933 {'bagging_freq': 4, 'learning_rate': 0.15354767338890413, 'max_bin': 12, 'n_estimators': 149, 'num_leaves': 68}
# 0.8488240181510242 {'bagging_freq': 9, 'learning_rate': 0.16446175918028305, 'max_bin': 163, 'n_estimators': 150, 'num_leaves': 35}
# 0.8491515674431981 {'bagging_freq': 7, 'learning_rate': 0.17394261887482831, 'max_bin': 149, 'n_estimators': 140, 'num_leaves': 13}
# 0.8491755344645766 {'bagging_freq': 8, 'learning_rate': 0.18996580804241522, 'max_bin': 77, 'n_estimators': 135, 'num_leaves': 73}
# 0.8491915124788292 {'bagging_freq': 4, 'learning_rate': 0.011368434554410424, 'max_bin': 20, 'n_estimators': 88, 'num_leaves': 73}
# 0.8494471607068673 {'bagging_freq': 5, 'learning_rate': 0.015012636974581276, 'max_bin': 12, 'n_estimators': 67, 'num_leaves': 87}
# 0.8494631387211197 {'bagging_freq': 1, 'learning_rate': 0.10989876816714897, 'max_bin': 53, 'n_estimators': 198, 'num_leaves': 86}
# 0.8495590068066342 {'bagging_freq': 7, 'learning_rate': 0.10806522093915492, 'max_bin': 154, 'n_estimators': 190, 'num_leaves': 48}
# 0.8497427539705367 {'bagging_freq': 5, 'learning_rate': 0.15620383965578283, 'max_bin': 77, 'n_estimators': 171, 'num_leaves': 94}
# 0.8497826990061675 {'bagging_freq': 8, 'learning_rate': 0.13627393929343787, 'max_bin': 151, 'n_estimators': 172, 'num_leaves': 14}
# 0.8497826990061677 {'bagging_freq': 2, 'learning_rate': 0.15533144792152248, 'max_bin': 190, 'n_estimators': 109, 'num_leaves': 23}
# 0.849886556098808 {'bagging_freq': 9, 'learning_rate': 0.1125438726156799, 'max_bin': 186, 'n_estimators': 185, 'num_leaves': 41}
# 0.849886556098808 {'bagging_freq': 6, 'learning_rate': 0.10986826009403806, 'max_bin': 42, 'n_estimators': 191, 'num_leaves': 47}
# 0.850014380212827 {'bagging_freq': 5, 'learning_rate': 0.021032928062915752, 'max_bin': 161, 'n_estimators': 39, 'num_leaves': 4}
# 0.8501182373054676 {'bagging_freq': 2, 'learning_rate': 0.0433916716175508, 'max_bin': 152, 'n_estimators': 28, 'num_leaves': 94}
# 0.8501262263125938 {'bagging_freq': 3, 'learning_rate': 0.0850127767976354, 'max_bin': 87, 'n_estimators': 189, 'num_leaves': 28}
# 0.85013421531972 {'bagging_freq': 4, 'learning_rate': 0.13164763351677652, 'max_bin': 104, 'n_estimators': 184, 'num_leaves': 65}
# 0.850214105390982 {'bagging_freq': 2, 'learning_rate': 0.18005813090132372, 'max_bin': 164, 'n_estimators': 123, 'num_leaves': 68}
# 0.8502780174479916 {'bagging_freq': 5, 'learning_rate': 0.17870242381390966, 'max_bin': 50, 'n_estimators': 142, 'num_leaves': 23}
# 0.8503099734764963 {'bagging_freq': 6, 'learning_rate': 0.19110079860651932, 'max_bin': 61, 'n_estimators': 85, 'num_leaves': 47}
# 0.8503579075192536 {'bagging_freq': 3, 'learning_rate': 0.18669640344197372, 'max_bin': 39, 'n_estimators': 97, 'num_leaves': 65}
# 0.8504537756047679 {'bagging_freq': 8, 'learning_rate': 0.13061861724145898, 'max_bin': 22, 'n_estimators': 164, 'num_leaves': 32}
# 0.8505975777330395 {'bagging_freq': 6, 'learning_rate': 0.02662499039095043, 'max_bin': 145, 'n_estimators': 46, 'num_leaves': 61}
# 0.8506455117757965 {'bagging_freq': 1, 'learning_rate': 0.1819273102884089, 'max_bin': 171, 'n_estimators': 102, 'num_leaves': 66}
# 0.8508132809254466 {'bagging_freq': 8, 'learning_rate': 0.12805692750932063, 'max_bin': 138, 'n_estimators': 196, 'num_leaves': 66}
# 0.8508931709967085 {'bagging_freq': 8, 'learning_rate': 0.14707409483583456, 'max_bin': 33, 'n_estimators': 176, 'num_leaves': 94}
# 0.8509331160323396 {'bagging_freq': 9, 'learning_rate': 0.009273027318897033, 'max_bin': 193, 'n_estimators': 141, 'num_leaves': 14}
# 0.8509570830537179 {'bagging_freq': 9, 'learning_rate': 0.1368716221359705, 'max_bin': 27, 'n_estimators': 177, 'num_leaves': 31}
# 0.8510050170964752 {'bagging_freq': 4, 'learning_rate': 0.1660374087649905, 'max_bin': 108, 'n_estimators': 99, 'num_leaves': 62}
# 0.8511727862461254 {'bagging_freq': 2, 'learning_rate': 0.09408281908925116, 'max_bin': 128, 'n_estimators': 179, 'num_leaves': 95}
# 0.8513006103601445 {'bagging_freq': 2, 'learning_rate': 0.14623202446358022, 'max_bin': 85, 'n_estimators': 121, 'num_leaves': 97}
# 0.8513405553957755 {'bagging_freq': 6, 'learning_rate': 0.1971896302690598, 'max_bin': 151, 'n_estimators': 116, 'num_leaves': 57}
# 0.8515962036238135 {'bagging_freq': 5, 'learning_rate': 0.18288300882994268, 'max_bin': 88, 'n_estimators': 86, 'num_leaves': 75}
# 0.8516601156808232 {'bagging_freq': 2, 'learning_rate': 0.1484826557097396, 'max_bin': 140, 'n_estimators': 103, 'num_leaves': 52}
# 0.8517320167449589 {'bagging_freq': 6, 'learning_rate': 0.18960501229521023, 'max_bin': 83, 'n_estimators': 65, 'num_leaves': 58}
# 0.8519636979516184 {'bagging_freq': 6, 'learning_rate': 0.13482245698366227, 'max_bin': 50, 'n_estimators': 78, 'num_leaves': 47}
# 0.8519636979516186 {'bagging_freq': 7, 'learning_rate': 0.12411724032837237, 'max_bin': 96, 'n_estimators': 139, 'num_leaves': 55}
# 0.8520835330585114 {'bagging_freq': 3, 'learning_rate': 0.13948762894156153, 'max_bin': 101, 'n_estimators': 141, 'num_leaves': 55}
# 0.8521873901511521 {'bagging_freq': 1, 'learning_rate': 0.12808784469404388, 'max_bin': 42, 'n_estimators': 113, 'num_leaves': 76}
# 0.8522033681654045 {'bagging_freq': 9, 'learning_rate': 0.1952665505936666, 'max_bin': 166, 'n_estimators': 127, 'num_leaves': 95}
# 0.8522672802224139 {'bagging_freq': 4, 'learning_rate': 0.1606761480443091, 'max_bin': 142, 'n_estimators': 124, 'num_leaves': 32}
# 0.8522912472437925 {'bagging_freq': 2, 'learning_rate': 0.013910044149027488, 'max_bin': 51, 'n_estimators': 65, 'num_leaves': 7}
# 0.8523471702936758 {'bagging_freq': 7, 'learning_rate': 0.13320855698168577, 'max_bin': 192, 'n_estimators': 96, 'num_leaves': 62}
# 0.8523791263221807 {'bagging_freq': 7, 'learning_rate': 0.17542989914142487, 'max_bin': 51, 'n_estimators': 56, 'num_leaves': 42}
# 0.8525229284504521 {'bagging_freq': 9, 'learning_rate': 0.08740008777260046, 'max_bin': 31, 'n_estimators': 137, 'num_leaves': 16}
# 0.8525708624932093 {'bagging_freq': 3, 'learning_rate': 0.11466108634980784, 'max_bin': 72, 'n_estimators': 138, 'num_leaves': 77}
# 0.8526267855430927 {'bagging_freq': 1, 'learning_rate': 0.1870357736161387, 'max_bin': 174, 'n_estimators': 83, 'num_leaves': 50}
# 0.8526427635573451 {'bagging_freq': 1, 'learning_rate': 0.1381183963781616, 'max_bin': 164, 'n_estimators': 144, 'num_leaves': 99}
# 0.8527546096571117 {'bagging_freq': 1, 'learning_rate': 0.17153814959624028, 'max_bin': 122, 'n_estimators': 166, 'num_leaves': 11}
# 0.8528984117853832 {'bagging_freq': 3, 'learning_rate': 0.1637894573875715, 'max_bin': 125, 'n_estimators': 103, 'num_leaves': 30}
# 0.8529543348352666 {'bagging_freq': 2, 'learning_rate': 0.11333612549007363, 'max_bin': 193, 'n_estimators': 129, 'num_leaves': 61}
# 0.8529783018566454 {'bagging_freq': 2, 'learning_rate': 0.17565477144195726, 'max_bin': 34, 'n_estimators': 123, 'num_leaves': 60}
# 0.8530422139136549 {'bagging_freq': 7, 'learning_rate': 0.1547852378780058, 'max_bin': 86, 'n_estimators': 70, 'num_leaves': 28}
# 0.8531221039849167 {'bagging_freq': 7, 'learning_rate': 0.1531284938806914, 'max_bin': 135, 'n_estimators': 68, 'num_leaves': 40}
# 0.853170038027674 {'bagging_freq': 7, 'learning_rate': 0.16042590759960457, 'max_bin': 186, 'n_estimators': 113, 'num_leaves': 38}
# 0.8532738951203145 {'bagging_freq': 7, 'learning_rate': 0.1296081298418847, 'max_bin': 67, 'n_estimators': 174, 'num_leaves': 16}
# 0.853297862141693 {'bagging_freq': 7, 'learning_rate': 0.05071066397256316, 'max_bin': 23, 'n_estimators': 151, 'num_leaves': 21}
# 0.8533058511488192 {'bagging_freq': 2, 'learning_rate': 0.011970498489745168, 'max_bin': 128, 'n_estimators': 76, 'num_leaves': 6}
# 0.8533218291630716 {'bagging_freq': 2, 'learning_rate': 0.1459716864958277, 'max_bin': 144, 'n_estimators': 195, 'num_leaves': 12}
# 0.8534975873198478 {'bagging_freq': 8, 'learning_rate': 0.1008827743125022, 'max_bin': 110, 'n_estimators': 189, 'num_leaves': 31}
# 0.8534975873198478 {'bagging_freq': 5, 'learning_rate': 0.0876588819955716, 'max_bin': 57, 'n_estimators': 168, 'num_leaves': 19}
# 0.8535535103697313 {'bagging_freq': 1, 'learning_rate': 0.12156065605770565, 'max_bin': 129, 'n_estimators': 135, 'num_leaves': 45}
# 0.8538171476048957 {'bagging_freq': 1, 'learning_rate': 0.161708825548926, 'max_bin': 122, 'n_estimators': 105, 'num_leaves': 56}
# 0.8539210046975362 {'bagging_freq': 3, 'learning_rate': 0.14063622358967146, 'max_bin': 157, 'n_estimators': 88, 'num_leaves': 94}
# 0.8539689387402933 {'bagging_freq': 4, 'learning_rate': 0.13508732801869497, 'max_bin': 84, 'n_estimators': 88, 'num_leaves': 69}
# 0.8540727958329338 {'bagging_freq': 8, 'learning_rate': 0.09599956542431237, 'max_bin': 40, 'n_estimators': 126, 'num_leaves': 78}
# 0.8540967628543125 {'bagging_freq': 2, 'learning_rate': 0.15640911857313644, 'max_bin': 23, 'n_estimators': 68, 'num_leaves': 41}
# 0.8542405649825839 {'bagging_freq': 3, 'learning_rate': 0.05992174407473041, 'max_bin': 59, 'n_estimators': 185, 'num_leaves': 87}
# 0.8542884990253411 {'bagging_freq': 1, 'learning_rate': 0.1306788163552497, 'max_bin': 130, 'n_estimators': 133, 'num_leaves': 35}
# 0.8543124660467196 {'bagging_freq': 8, 'learning_rate': 0.12628048412100407, 'max_bin': 159, 'n_estimators': 146, 'num_leaves': 21}
# 0.8543284440609721 {'bagging_freq': 4, 'learning_rate': 0.14414550037929927, 'max_bin': 40, 'n_estimators': 93, 'num_leaves': 95}
# 0.8543284440609721 {'bagging_freq': 3, 'learning_rate': 0.14776082864338067, 'max_bin': 83, 'n_estimators': 88, 'num_leaves': 47}
# 0.8546719713673984 {'bagging_freq': 6, 'learning_rate': 0.0972707106311827, 'max_bin': 20, 'n_estimators': 97, 'num_leaves': 56}
# 0.8548796855526795 {'bagging_freq': 5, 'learning_rate': 0.09076464198715796, 'max_bin': 28, 'n_estimators': 169, 'num_leaves': 52}
# 0.8549196305883106 {'bagging_freq': 6, 'learning_rate': 0.02226847210707164, 'max_bin': 14, 'n_estimators': 64, 'num_leaves': 57}
# 0.8549276195954365 {'bagging_freq': 5, 'learning_rate': 0.11539765493024068, 'max_bin': 55, 'n_estimators': 125, 'num_leaves': 44}
# 0.8549356086025628 {'bagging_freq': 9, 'learning_rate': 0.1570737524311274, 'max_bin': 42, 'n_estimators': 88, 'num_leaves': 22}
# 0.8551832678234749 {'bagging_freq': 2, 'learning_rate': 0.17815341930079237, 'max_bin': 47, 'n_estimators': 57, 'num_leaves': 56}
# 0.8552312018662321 {'bagging_freq': 7, 'learning_rate': 0.0851426133277653, 'max_bin': 152, 'n_estimators': 140, 'num_leaves': 83}
# 0.8552551688876107 {'bagging_freq': 8, 'learning_rate': 0.10515910355407941, 'max_bin': 82, 'n_estimators': 103, 'num_leaves': 50}
# 0.855271146901863 {'bagging_freq': 6, 'learning_rate': 0.1550192871201904, 'max_bin': 191, 'n_estimators': 195, 'num_leaves': 10}
# 0.8553670149873773 {'bagging_freq': 3, 'learning_rate': 0.09998133262595774, 'max_bin': 182, 'n_estimators': 94, 'num_leaves': 76}
# 0.8553750039945036 {'bagging_freq': 3, 'learning_rate': 0.052038052143611915, 'max_bin': 59, 'n_estimators': 194, 'num_leaves': 40}
# 0.8554548940657655 {'bagging_freq': 8, 'learning_rate': 0.09343823578016316, 'max_bin': 180, 'n_estimators': 156, 'num_leaves': 40}
# 0.8555188061227751 {'bagging_freq': 4, 'learning_rate': 0.05953053300080954, 'max_bin': 183, 'n_estimators': 169, 'num_leaves': 91}
# 0.8555188061227751 {'bagging_freq': 5, 'learning_rate': 0.17901452959054326, 'max_bin': 140, 'n_estimators': 89, 'num_leaves': 49}
# 0.8556626082510466 {'bagging_freq': 1, 'learning_rate': 0.08749524053475631, 'max_bin': 153, 'n_estimators': 129, 'num_leaves': 81}
# 0.8558383664078228 {'bagging_freq': 9, 'learning_rate': 0.056900599178429, 'max_bin': 89, 'n_estimators': 30, 'num_leaves': 35}
# 0.85588630045058 {'bagging_freq': 8, 'learning_rate': 0.1333260196875211, 'max_bin': 47, 'n_estimators': 74, 'num_leaves': 90}
# 0.8558942894577062 {'bagging_freq': 9, 'learning_rate': 0.07854739488708792, 'max_bin': 194, 'n_estimators': 140, 'num_leaves': 91}
# 0.8559022784648325 {'bagging_freq': 1, 'learning_rate': 0.08080069754767541, 'max_bin': 106, 'n_estimators': 154, 'num_leaves': 50}
# 0.856006135557473 {'bagging_freq': 9, 'learning_rate': 0.06507083042058172, 'max_bin': 16, 'n_estimators': 176, 'num_leaves': 52}
# 0.856014124564599 {'bagging_freq': 4, 'learning_rate': 0.11505332039036792, 'max_bin': 59, 'n_estimators': 81, 'num_leaves': 78}
# 0.8561259706643658 {'bagging_freq': 6, 'learning_rate': 0.05262614537825186, 'max_bin': 33, 'n_estimators': 23, 'num_leaves': 28}
# 0.8561818937142491 {'bagging_freq': 8, 'learning_rate': 0.008402554421771447, 'max_bin': 20, 'n_estimators': 156, 'num_leaves': 77}
# 0.8562058607356278 {'bagging_freq': 1, 'learning_rate': 0.07730377441916889, 'max_bin': 41, 'n_estimators': 179, 'num_leaves': 51}
# 0.8562697727926374 {'bagging_freq': 7, 'learning_rate': 0.07200214338310183, 'max_bin': 15, 'n_estimators': 133, 'num_leaves': 41}
# 0.8562777617997634 {'bagging_freq': 6, 'learning_rate': 0.11864927898179073, 'max_bin': 167, 'n_estimators': 94, 'num_leaves': 63}
# 0.8563017288211422 {'bagging_freq': 5, 'learning_rate': 0.12110835078740181, 'max_bin': 150, 'n_estimators': 74, 'num_leaves': 90}
# 0.8563736298852779 {'bagging_freq': 3, 'learning_rate': 0.1327073036470835, 'max_bin': 149, 'n_estimators': 56, 'num_leaves': 74}
# 0.8565094430064232 {'bagging_freq': 1, 'learning_rate': 0.0785001329020768, 'max_bin': 173, 'n_estimators': 139, 'num_leaves': 30}
# 0.8565733550634328 {'bagging_freq': 8, 'learning_rate': 0.10107131505544287, 'max_bin': 65, 'n_estimators': 72, 'num_leaves': 69}
# 0.8565973220848113 {'bagging_freq': 3, 'learning_rate': 0.12962484785167552, 'max_bin': 107, 'n_estimators': 57, 'num_leaves': 46}
# 0.8566692231489471 {'bagging_freq': 1, 'learning_rate': 0.14405343600485185, 'max_bin': 87, 'n_estimators': 53, 'num_leaves': 96}
# 0.8567411242130829 {'bagging_freq': 4, 'learning_rate': 0.1222679415678802, 'max_bin': 183, 'n_estimators': 108, 'num_leaves': 62}
# 0.8567810692487137 {'bagging_freq': 6, 'learning_rate': 0.055577460045689836, 'max_bin': 41, 'n_estimators': 162, 'num_leaves': 82}
# 0.8568210142843448 {'bagging_freq': 4, 'learning_rate': 0.13017465165947634, 'max_bin': 53, 'n_estimators': 74, 'num_leaves': 45}
# 0.8569648164126161 {'bagging_freq': 5, 'learning_rate': 0.009312327017934413, 'max_bin': 32, 'n_estimators': 152, 'num_leaves': 99}
# 0.8569728054197424 {'bagging_freq': 9, 'learning_rate': 0.10142066940400124, 'max_bin': 163, 'n_estimators': 86, 'num_leaves': 83}
# 0.8569887834339949 {'bagging_freq': 6, 'learning_rate': 0.07820990381573616, 'max_bin': 39, 'n_estimators': 24, 'num_leaves': 23}
# 0.8570287284696259 {'bagging_freq': 7, 'learning_rate': 0.11094433040281935, 'max_bin': 92, 'n_estimators': 164, 'num_leaves': 2}
# 0.8570447064838782 {'bagging_freq': 2, 'learning_rate': 0.053781245284911315, 'max_bin': 138, 'n_estimators': 156, 'num_leaves': 37}
# 0.8571485635765186 {'bagging_freq': 1, 'learning_rate': 0.09277759872726354, 'max_bin': 157, 'n_estimators': 172, 'num_leaves': 45}
# 0.8571885086121496 {'bagging_freq': 2, 'learning_rate': 0.14838869944109806, 'max_bin': 122, 'n_estimators': 171, 'num_leaves': 2}
# 0.8571885086121498 {'bagging_freq': 2, 'learning_rate': 0.12695773900750704, 'max_bin': 134, 'n_estimators': 116, 'num_leaves': 92}
# 0.857196497619276 {'bagging_freq': 8, 'learning_rate': 0.08322005709434391, 'max_bin': 168, 'n_estimators': 126, 'num_leaves': 47}
# 0.8572604096762854 {'bagging_freq': 7, 'learning_rate': 0.14379218490535234, 'max_bin': 40, 'n_estimators': 39, 'num_leaves': 9}
# 0.8574841018758188 {'bagging_freq': 5, 'learning_rate': 0.13210549079311792, 'max_bin': 131, 'n_estimators': 71, 'num_leaves': 94}
# 0.8575160579043237 {'bagging_freq': 2, 'learning_rate': 0.06867349582460502, 'max_bin': 190, 'n_estimators': 155, 'num_leaves': 94}
# 0.8575560029399547 {'bagging_freq': 9, 'learning_rate': 0.02724869395452195, 'max_bin': 84, 'n_estimators': 78, 'num_leaves': 33}
# 0.8575719809542071 {'bagging_freq': 8, 'learning_rate': 0.024276403360078455, 'max_bin': 187, 'n_estimators': 74, 'num_leaves': 12}
# 0.8576039369827119 {'bagging_freq': 3, 'learning_rate': 0.19799291267659283, 'max_bin': 117, 'n_estimators': 37, 'num_leaves': 54}
# 0.8576678490397214 {'bagging_freq': 6, 'learning_rate': 0.11977212253290674, 'max_bin': 102, 'n_estimators': 134, 'num_leaves': 19}
# 0.8576838270539738 {'bagging_freq': 4, 'learning_rate': 0.09050693817704775, 'max_bin': 126, 'n_estimators': 109, 'num_leaves': 63}
# 0.8577317610967309 {'bagging_freq': 3, 'learning_rate': 0.06516455368311237, 'max_bin': 79, 'n_estimators': 90, 'num_leaves': 74}
# 0.8577317610967309 {'bagging_freq': 4, 'learning_rate': 0.0510263045598931, 'max_bin': 100, 'n_estimators': 171, 'num_leaves': 45}
# 0.85785958521075 {'bagging_freq': 7, 'learning_rate': 0.08693330443309967, 'max_bin': 69, 'n_estimators': 99, 'num_leaves': 77}
# 0.8579075192535072 {'bagging_freq': 1, 'learning_rate': 0.051070861299701564, 'max_bin': 17, 'n_estimators': 97, 'num_leaves': 18}
# 0.8579234972677596 {'bagging_freq': 7, 'learning_rate': 0.14684549351187323, 'max_bin': 142, 'n_estimators': 67, 'num_leaves': 58}
# 0.8579394752820118 {'bagging_freq': 6, 'learning_rate': 0.07430308195263718, 'max_bin': 125, 'n_estimators': 152, 'num_leaves': 31}
# 0.8579474642891382 {'bagging_freq': 1, 'learning_rate': 0.12005398428679435, 'max_bin': 132, 'n_estimators': 86, 'num_leaves': 24}
# 0.8579714313105168 {'bagging_freq': 3, 'learning_rate': 0.061123109305981964, 'max_bin': 147, 'n_estimators': 152, 'num_leaves': 29}
# 0.858019365353274 {'bagging_freq': 6, 'learning_rate': 0.05369453454548555, 'max_bin': 46, 'n_estimators': 35, 'num_leaves': 82}
# 0.8580672993960311 {'bagging_freq': 6, 'learning_rate': 0.19371422704215305, 'max_bin': 184, 'n_estimators': 34, 'num_leaves': 21}
# 0.8582430575528074 {'bagging_freq': 7, 'learning_rate': 0.1318278506472097, 'max_bin': 175, 'n_estimators': 45, 'num_leaves': 70}
# 0.858306969609817 {'bagging_freq': 6, 'learning_rate': 0.15222678227219566, 'max_bin': 10, 'n_estimators': 59, 'num_leaves': 18}
# 0.8583149586169432 {'bagging_freq': 4, 'learning_rate': 0.04318604465246259, 'max_bin': 184, 'n_estimators': 48, 'num_leaves': 46}
# 0.8583628926597001 {'bagging_freq': 3, 'learning_rate': 0.1272415938581339, 'max_bin': 77, 'n_estimators': 67, 'num_leaves': 18}
# 0.8583868596810789 {'bagging_freq': 9, 'learning_rate': 0.06696343923874913, 'max_bin': 14, 'n_estimators': 134, 'num_leaves': 26}
# 0.8584028376953313 {'bagging_freq': 9, 'learning_rate': 0.060714298786188364, 'max_bin': 176, 'n_estimators': 33, 'num_leaves': 15}
# 0.8584268047167098 {'bagging_freq': 2, 'learning_rate': 0.07789589002259477, 'max_bin': 30, 'n_estimators': 98, 'num_leaves': 68}
# 0.8584507717380884 {'bagging_freq': 7, 'learning_rate': 0.06249955303699104, 'max_bin': 106, 'n_estimators': 90, 'num_leaves': 82}
# 0.8584987057808456 {'bagging_freq': 6, 'learning_rate': 0.04495148866840568, 'max_bin': 167, 'n_estimators': 174, 'num_leaves': 29}
# 0.8585386508164765 {'bagging_freq': 5, 'learning_rate': 0.09311447270233354, 'max_bin': 189, 'n_estimators': 74, 'num_leaves': 44}
# 0.8585466398236027 {'bagging_freq': 4, 'learning_rate': 0.10783062479499961, 'max_bin': 44, 'n_estimators': 67, 'num_leaves': 52}
# 0.8586345189019908 {'bagging_freq': 1, 'learning_rate': 0.043742782390533405, 'max_bin': 160, 'n_estimators': 178, 'num_leaves': 66}
# 0.8587383759946314 {'bagging_freq': 7, 'learning_rate': 0.015075542412671082, 'max_bin': 36, 'n_estimators': 105, 'num_leaves': 75}
# 0.85876234301601 {'bagging_freq': 1, 'learning_rate': 0.040164180157610994, 'max_bin': 30, 'n_estimators': 144, 'num_leaves': 95}
# 0.8588022880516409 {'bagging_freq': 9, 'learning_rate': 0.05516977978689427, 'max_bin': 18, 'n_estimators': 85, 'num_leaves': 22}
# 0.8588022880516409 {'bagging_freq': 6, 'learning_rate': 0.031055408211438734, 'max_bin': 19, 'n_estimators': 167, 'num_leaves': 39}
# 0.8588582111015243 {'bagging_freq': 4, 'learning_rate': 0.12401895474167213, 'max_bin': 195, 'n_estimators': 20, 'num_leaves': 14}
# 0.8589540791870387 {'bagging_freq': 1, 'learning_rate': 0.0457189759950726, 'max_bin': 145, 'n_estimators': 152, 'num_leaves': 71}
# 0.858970057201291 {'bagging_freq': 4, 'learning_rate': 0.10280373223168975, 'max_bin': 96, 'n_estimators': 85, 'num_leaves': 79}
# 0.8590739142939315 {'bagging_freq': 1, 'learning_rate': 0.11658863455185682, 'max_bin': 171, 'n_estimators': 65, 'num_leaves': 42}
# 0.8590739142939317 {'bagging_freq': 9, 'learning_rate': 0.056783586439645255, 'max_bin': 99, 'n_estimators': 153, 'num_leaves': 57}
# 0.8591218483366887 {'bagging_freq': 9, 'learning_rate': 0.09165116231782734, 'max_bin': 95, 'n_estimators': 61, 'num_leaves': 94}
# 0.8591857603936982 {'bagging_freq': 7, 'learning_rate': 0.06855127545282966, 'max_bin': 105, 'n_estimators': 114, 'num_leaves': 70}
# 0.8592257054293293 {'bagging_freq': 4, 'learning_rate': 0.08405528916203768, 'max_bin': 18, 'n_estimators': 42, 'num_leaves': 72}
# 0.8592336944364555 {'bagging_freq': 2, 'learning_rate': 0.045807609984239835, 'max_bin': 91, 'n_estimators': 75, 'num_leaves': 19}
# 0.8592496724507078 {'bagging_freq': 6, 'learning_rate': 0.03320379964044602, 'max_bin': 90, 'n_estimators': 183, 'num_leaves': 70}
# 0.8592656504649602 {'bagging_freq': 9, 'learning_rate': 0.15477844115587036, 'max_bin': 67, 'n_estimators': 50, 'num_leaves': 57}
# 0.8593295625219697 {'bagging_freq': 2, 'learning_rate': 0.1524558641001155, 'max_bin': 173, 'n_estimators': 35, 'num_leaves': 22}
# 0.8593615185504745 {'bagging_freq': 9, 'learning_rate': 0.09218643797473255, 'max_bin': 168, 'n_estimators': 123, 'num_leaves': 22}
# 0.8593854855718529 {'bagging_freq': 4, 'learning_rate': 0.10885060474881814, 'max_bin': 72, 'n_estimators': 20, 'num_leaves': 81}
# 0.8594014635861055 {'bagging_freq': 1, 'learning_rate': 0.060555145606642886, 'max_bin': 22, 'n_estimators': 77, 'num_leaves': 42}
# 0.8595053206787461 {'bagging_freq': 1, 'learning_rate': 0.10555003646725869, 'max_bin': 113, 'n_estimators': 61, 'num_leaves': 18}
# 0.8595053206787461 {'bagging_freq': 1, 'learning_rate': 0.07350295238100178, 'max_bin': 60, 'n_estimators': 80, 'num_leaves': 18}
# 0.859545265714377 {'bagging_freq': 2, 'learning_rate': 0.1020306608326575, 'max_bin': 76, 'n_estimators': 69, 'num_leaves': 74}
# 0.8595532547215032 {'bagging_freq': 1, 'learning_rate': 0.11781123071087737, 'max_bin': 104, 'n_estimators': 75, 'num_leaves': 71}
# 0.8595852107500079 {'bagging_freq': 1, 'learning_rate': 0.12393458245119346, 'max_bin': 59, 'n_estimators': 49, 'num_leaves': 33}
# 0.8596091777713866 {'bagging_freq': 4, 'learning_rate': 0.019323432749139002, 'max_bin': 123, 'n_estimators': 109, 'num_leaves': 76}
# 0.8596331447927652 {'bagging_freq': 5, 'learning_rate': 0.037221995281267704, 'max_bin': 143, 'n_estimators': 62, 'num_leaves': 78}
# 0.8596411337998913 {'bagging_freq': 2, 'learning_rate': 0.08576405704399805, 'max_bin': 115, 'n_estimators': 124, 'num_leaves': 84}
# 0.8597370018854056 {'bagging_freq': 8, 'learning_rate': 0.04378953232675701, 'max_bin': 137, 'n_estimators': 172, 'num_leaves': 86}
# 0.85983286997092 {'bagging_freq': 9, 'learning_rate': 0.0621824779157069, 'max_bin': 122, 'n_estimators': 107, 'num_leaves': 38}
# 0.8598488479851724 {'bagging_freq': 8, 'learning_rate': 0.09805730538083016, 'max_bin': 36, 'n_estimators': 111, 'num_leaves': 91}
# 0.8598488479851724 {'bagging_freq': 6, 'learning_rate': 0.1554913209885183, 'max_bin': 67, 'n_estimators': 56, 'num_leaves': 77}
# 0.8598568369922986 {'bagging_freq': 8, 'learning_rate': 0.07040251875528833, 'max_bin': 45, 'n_estimators': 81, 'num_leaves': 9}
# 0.8599367270635606 {'bagging_freq': 5, 'learning_rate': 0.06364567231279908, 'max_bin': 100, 'n_estimators': 74, 'num_leaves': 98}
# 0.8599527050778127 {'bagging_freq': 8, 'learning_rate': 0.06914956495482695, 'max_bin': 197, 'n_estimators': 108, 'num_leaves': 88}
# 0.8599766720991915 {'bagging_freq': 1, 'learning_rate': 0.17040762267135287, 'max_bin': 48, 'n_estimators': 24, 'num_leaves': 11}
# 0.8600166171348225 {'bagging_freq': 9, 'learning_rate': 0.057510442033257204, 'max_bin': 108, 'n_estimators': 146, 'num_leaves': 76}
# 0.8600885181989583 {'bagging_freq': 1, 'learning_rate': 0.07654054156379275, 'max_bin': 137, 'n_estimators': 97, 'num_leaves': 77}
# 0.8601364522417154 {'bagging_freq': 4, 'learning_rate': 0.028193722212110486, 'max_bin': 138, 'n_estimators': 84, 'num_leaves': 63}
# 0.8602243313201036 {'bagging_freq': 1, 'learning_rate': 0.011339422131365427, 'max_bin': 53, 'n_estimators': 110, 'num_leaves': 7}
# 0.8603042213913654 {'bagging_freq': 6, 'learning_rate': 0.028038239117095663, 'max_bin': 174, 'n_estimators': 86, 'num_leaves': 95}
# 0.8605199245837728 {'bagging_freq': 8, 'learning_rate': 0.029331913462097806, 'max_bin': 119, 'n_estimators': 154, 'num_leaves': 13}
# 0.8605998146550347 {'bagging_freq': 8, 'learning_rate': 0.10072297226832765, 'max_bin': 120, 'n_estimators': 62, 'num_leaves': 92}
# 0.8605998146550347 {'bagging_freq': 3, 'learning_rate': 0.04596065422522296, 'max_bin': 148, 'n_estimators': 142, 'num_leaves': 51}
# 0.8605998146550347 {'bagging_freq': 2, 'learning_rate': 0.09568328219015641, 'max_bin': 129, 'n_estimators': 47, 'num_leaves': 25}
# 0.8606397596906656 {'bagging_freq': 6, 'learning_rate': 0.050693921961960285, 'max_bin': 184, 'n_estimators': 95, 'num_leaves': 26}
# 0.8606557377049179 {'bagging_freq': 9, 'learning_rate': 0.10047661766428644, 'max_bin': 78, 'n_estimators': 196, 'num_leaves': 9}
# 0.860823506854568 {'bagging_freq': 2, 'learning_rate': 0.07478591390720546, 'max_bin': 141, 'n_estimators': 88, 'num_leaves': 63}
# 0.860823506854568 {'bagging_freq': 2, 'learning_rate': 0.03945919010870878, 'max_bin': 142, 'n_estimators': 159, 'num_leaves': 64}
# 0.8609673089828397 {'bagging_freq': 7, 'learning_rate': 0.12244324456426348, 'max_bin': 144, 'n_estimators': 155, 'num_leaves': 8}
# 0.8610312210398491 {'bagging_freq': 6, 'learning_rate': 0.061453085827919196, 'max_bin': 71, 'n_estimators': 67, 'num_leaves': 40}
# 0.8610711660754802 {'bagging_freq': 2, 'learning_rate': 0.07221482776797564, 'max_bin': 81, 'n_estimators': 55, 'num_leaves': 66}
# 0.8610711660754802 {'bagging_freq': 1, 'learning_rate': 0.13747933193809758, 'max_bin': 84, 'n_estimators': 28, 'num_leaves': 42}
# 0.8610711660754802 {'bagging_freq': 7, 'learning_rate': 0.05281103599643698, 'max_bin': 74, 'n_estimators': 156, 'num_leaves': 8}
# 0.861151056146742 {'bagging_freq': 2, 'learning_rate': 0.04756992317858423, 'max_bin': 161, 'n_estimators': 96, 'num_leaves': 54}
# 0.861183012175247 {'bagging_freq': 7, 'learning_rate': 0.015265922705362589, 'max_bin': 160, 'n_estimators': 156, 'num_leaves': 19}
# 0.8613268143035185 {'bagging_freq': 1, 'learning_rate': 0.05003233521285846, 'max_bin': 138, 'n_estimators': 53, 'num_leaves': 23}
# 0.8613348033106446 {'bagging_freq': 4, 'learning_rate': 0.07617540953153193, 'max_bin': 191, 'n_estimators': 99, 'num_leaves': 47}
# 0.861398715367654 {'bagging_freq': 6, 'learning_rate': 0.10935997072667919, 'max_bin': 198, 'n_estimators': 35, 'num_leaves': 94}
# 0.8614865944460423 {'bagging_freq': 1, 'learning_rate': 0.19045124215575915, 'max_bin': 41, 'n_estimators': 31, 'num_leaves': 88}
# 0.8617262646598279 {'bagging_freq': 8, 'learning_rate': 0.16869127114920915, 'max_bin': 82, 'n_estimators': 113, 'num_leaves': 6}
# 0.861894033809478 {'bagging_freq': 8, 'learning_rate': 0.02999020724330335, 'max_bin': 188, 'n_estimators': 146, 'num_leaves': 83}
# 0.8619579458664877 {'bagging_freq': 8, 'learning_rate': 0.030195322764826095, 'max_bin': 134, 'n_estimators': 153, 'num_leaves': 95}
# 0.8619659348736138 {'bagging_freq': 6, 'learning_rate': 0.08401675976393266, 'max_bin': 138, 'n_estimators': 31, 'num_leaves': 51}
# 0.8619899018949925 {'bagging_freq': 9, 'learning_rate': 0.03423007907514408, 'max_bin': 109, 'n_estimators': 127, 'num_leaves': 92}
# 0.8620697919662546 {'bagging_freq': 9, 'learning_rate': 0.03363247323985803, 'max_bin': 111, 'n_estimators': 91, 'num_leaves': 52}
# 0.8622056050873997 {'bagging_freq': 4, 'learning_rate': 0.10972095070038626, 'max_bin': 34, 'n_estimators': 87, 'num_leaves': 9}
# 0.8622056050873997 {'bagging_freq': 4, 'learning_rate': 0.026092759633907545, 'max_bin': 182, 'n_estimators': 109, 'num_leaves': 66}
# 0.8622135940945258 {'bagging_freq': 5, 'learning_rate': 0.04868196806148456, 'max_bin': 75, 'n_estimators': 98, 'num_leaves': 63}
# 0.8622854951586616 {'bagging_freq': 3, 'learning_rate': 0.10357420289190189, 'max_bin': 87, 'n_estimators': 28, 'num_leaves': 23}
# 0.8624372862940595 {'bagging_freq': 5, 'learning_rate': 0.16175925639991784, 'max_bin': 166, 'n_estimators': 28, 'num_leaves': 99}
# 0.8625651104080785 {'bagging_freq': 3, 'learning_rate': 0.05497134877052857, 'max_bin': 87, 'n_estimators': 82, 'num_leaves': 49}
# 0.8626450004793406 {'bagging_freq': 8, 'learning_rate': 0.027170982710038503, 'max_bin': 101, 'n_estimators': 121, 'num_leaves': 33}
# 0.8626689675007192 {'bagging_freq': 1, 'learning_rate': 0.11007256918254699, 'max_bin': 158, 'n_estimators': 36, 'num_leaves': 17}
# 0.8627408685648547 {'bagging_freq': 9, 'learning_rate': 0.02002407224943929, 'max_bin': 127, 'n_estimators': 169, 'num_leaves': 46}
# 0.8630843958712812 {'bagging_freq': 9, 'learning_rate': 0.027838061647982477, 'max_bin': 44, 'n_estimators': 100, 'num_leaves': 43}
# 0.8631802639567955 {'bagging_freq': 2, 'learning_rate': 0.027375213677160275, 'max_bin': 179, 'n_estimators': 134, 'num_leaves': 91}
# 0.8631882529639217 {'bagging_freq': 9, 'learning_rate': 0.06309698625345628, 'max_bin': 11, 'n_estimators': 39, 'num_leaves': 48}
# 0.8632122199853002 {'bagging_freq': 9, 'learning_rate': 0.020655874118087017, 'max_bin': 137, 'n_estimators': 191, 'num_leaves': 7}
# 0.8633560221135718 {'bagging_freq': 8, 'learning_rate': 0.09594928220764175, 'max_bin': 97, 'n_estimators': 34, 'num_leaves': 18}
# 0.8633640111206979 {'bagging_freq': 8, 'learning_rate': 0.030282366816396917, 'max_bin': 86, 'n_estimators': 95, 'num_leaves': 8}
# 0.8634279231777074 {'bagging_freq': 1, 'learning_rate': 0.026203512551595885, 'max_bin': 170, 'n_estimators': 149, 'num_leaves': 88}
# 0.8634359121848336 {'bagging_freq': 3, 'learning_rate': 0.14721264465071282, 'max_bin': 155, 'n_estimators': 22, 'num_leaves': 16}
# 0.8634678682133385 {'bagging_freq': 9, 'learning_rate': 0.09144195414063157, 'max_bin': 138, 'n_estimators': 51, 'num_leaves': 25}
# 0.8634998242418432 {'bagging_freq': 3, 'learning_rate': 0.04510564041149302, 'max_bin': 67, 'n_estimators': 107, 'num_leaves': 71}
# 0.8635237912632218 {'bagging_freq': 5, 'learning_rate': 0.07900831000629147, 'max_bin': 196, 'n_estimators': 61, 'num_leaves': 17}
# 0.8635317802703479 {'bagging_freq': 7, 'learning_rate': 0.07711971664703693, 'max_bin': 113, 'n_estimators': 25, 'num_leaves': 7}
# 0.8636036813344837 {'bagging_freq': 8, 'learning_rate': 0.036735801696422994, 'max_bin': 159, 'n_estimators': 120, 'num_leaves': 37}
# 0.8636276483558623 {'bagging_freq': 9, 'learning_rate': 0.03848951213173476, 'max_bin': 114, 'n_estimators': 105, 'num_leaves': 40}
# 0.8637634614770077 {'bagging_freq': 2, 'learning_rate': 0.06598781567568754, 'max_bin': 147, 'n_estimators': 46, 'num_leaves': 31}
# 0.8638513405553957 {'bagging_freq': 2, 'learning_rate': 0.04355537091821166, 'max_bin': 43, 'n_estimators': 95, 'num_leaves': 93}
# 0.8639312306266579 {'bagging_freq': 7, 'learning_rate': 0.10710468311871071, 'max_bin': 32, 'n_estimators': 37, 'num_leaves': 5}
# 0.8640031316907935 {'bagging_freq': 3, 'learning_rate': 0.06233209190803344, 'max_bin': 108, 'n_estimators': 171, 'num_leaves': 5}
# 0.8640590547406768 {'bagging_freq': 2, 'learning_rate': 0.08753338751131838, 'max_bin': 57, 'n_estimators': 111, 'num_leaves': 5}
# 0.8642667689259579 {'bagging_freq': 2, 'learning_rate': 0.12623308607230746, 'max_bin': 95, 'n_estimators': 23, 'num_leaves': 65}
# 0.8642987249544627 {'bagging_freq': 5, 'learning_rate': 0.037331532032801276, 'max_bin': 135, 'n_estimators': 81, 'num_leaves': 96}
# 0.8643306809829674 {'bagging_freq': 2, 'learning_rate': 0.06369093094867047, 'max_bin': 28, 'n_estimators': 101, 'num_leaves': 92}
# 0.8643626370114722 {'bagging_freq': 4, 'learning_rate': 0.042262443960215196, 'max_bin': 41, 'n_estimators': 77, 'num_leaves': 63}
# 0.8643706260185983 {'bagging_freq': 4, 'learning_rate': 0.1588221427819183, 'max_bin': 158, 'n_estimators': 79, 'num_leaves': 4}
# 0.8646981753107724 {'bagging_freq': 2, 'learning_rate': 0.02124303800956037, 'max_bin': 29, 'n_estimators': 124, 'num_leaves': 4}
# 0.8650177355958202 {'bagging_freq': 4, 'learning_rate': 0.13953593223987681, 'max_bin': 134, 'n_estimators': 40, 'num_leaves': 55}
# 0.8650417026171987 {'bagging_freq': 7, 'learning_rate': 0.11167808684830495, 'max_bin': 75, 'n_estimators': 101, 'num_leaves': 7}
# 0.8653772409164989 {'bagging_freq': 7, 'learning_rate': 0.12634672747799722, 'max_bin': 51, 'n_estimators': 106, 'num_leaves': 9}
# 0.8655609880804014 {'bagging_freq': 3, 'learning_rate': 0.08692412916184113, 'max_bin': 69, 'n_estimators': 99, 'num_leaves': 5}
# 0.8656328891445371 {'bagging_freq': 5, 'learning_rate': 0.10521789494514994, 'max_bin': 68, 'n_estimators': 132, 'num_leaves': 4}
# 0.8658166363084396 {'bagging_freq': 5, 'learning_rate': 0.07918437193316032, 'max_bin': 96, 'n_estimators': 191, 'num_leaves': 3}
# 0.8659444604224588 {'bagging_freq': 2, 'learning_rate': 0.07124269482293455, 'max_bin': 29, 'n_estimators': 175, 'num_leaves': 6}
# 0.8661441856006135 {'bagging_freq': 3, 'learning_rate': 0.19518643233260938, 'max_bin': 169, 'n_estimators': 104, 'num_leaves': 5}
# 0.8668152621992139 {'bagging_freq': 5, 'learning_rate': 0.13530883520349077, 'max_bin': 27, 'n_estimators': 25, 'num_leaves': 81}
# 0.8698990189499249 {'bagging_freq': 3, 'learning_rate': 0.15039533753345835, 'max_bin': 136, 'n_estimators': 29, 'num_leaves': 4}
# 0.8724954462659381 {'bagging_freq': 6, 'learning_rate': 0.11595545220262925, 'max_bin': 35, 'n_estimators': 53, 'num_leaves': 4}

# %%
parameters = {
    "learning_rate": uniform(0.001, 0.5),
 "n_estimators": list(range(1, 2000)),
 "max_depth": list(range(1, 100)),
 "min_child_weight": list(range(1, 200, 2)),
 "subsample": np.arange(0.2,1.01,0.2),
 "colsample_bytree": np.arange(0.2,1.01,0.2),
 "reg_alpha": uniform(0.001, 0.1)       
    } 

model = XGBClassifier()
randomsearch = RandomizedSearchCV(model,
                                  param_distributions=parameters,
                                  n_iter=200,
                                  cv=4,
                                  random_state=1,
                                  scoring=scoring,
                                  return_train_score=True,
                                  refit='Accuracy',
                                  verbose=0)

r = randomsearch.fit(data,y)
max(r.cv_results_['mean_test_AUC'])
# Out:
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# 0.8751240620334043

# %%
r.best_estimator_
xgb_best = r.best_estimator_

# %%
parameters = {
 "n_estimators": list(range(1, 5000)),
 "max_depth": list(range(1, 10)) + [None],
 "criterion": ["gini", "entropy"],   
 "min_samples_split": list(range(2,6)),
 "min_samples_leaf": list(range(1,5)),
 "max_features": ["auto", "sqrt", "log2"]   
    } 

model = RandomForestClassifier()
randomsearch = RandomizedSearchCV(model,
                                  param_distributions=parameters,
                                  n_iter=2000,
                                  cv=5,
                                  random_state=1,
                                  scoring=scoring,
                                  return_train_score=True,
                                  refit='Accuracy',
                                  verbose=0)

r = randomsearch.fit(data,y)
max(r.cv_results_['mean_test_AUC'])
# Out:
# 0.8742176979270336

# %%
for mean_score, params in sorted(list(zip(scores["mean_test_AUC"], scores["params"])),key = lambda x: x[0]):
    print(mean_score, params)
# Out:
# 0.8394121240710506 {'n_estimators': 121, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_features': 'auto', 'max_depth': 1, 'criterion': 'entropy'}
# 0.8395149620362695 {'n_estimators': 1517, 'min_samples_split': 2, 'min_samples_leaf': 4, 'max_features': 'log2', 'max_depth': 1, 'criterion': 'entropy'}
# 0.8395743531093607 {'n_estimators': 4844, 'min_samples_split': 4, 'min_samples_leaf': 4, 'max_features': 'sqrt', 'max_depth': 1, 'criterion': 'entropy'}
# 0.8397052563786066 {'n_estimators': 4144, 'min_samples_split': 4, 'min_samples_leaf': 1, 'max_features': 'auto', 'max_depth': 1, 'criterion': 'gini'}
# 0.8399792520700087 {'n_estimators': 3492, 'min_samples_split': 3, 'min_samples_leaf': 2, 'max_features': 'log2', 'max_depth': 1, 'criterion': 'gini'}
# 0.8399839061892859 {'n_estimators': 4325, 'min_samples_split': 3, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'max_depth': 1, 'criterion': 'entropy'}
# 0.8400441811516234 {'n_estimators': 4498, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_features': 'sqrt', 'max_depth': 1, 'criterion': 'entropy'}
# 0.8400779716759262 {'n_estimators': 3072, 'min_samples_split': 5, 'min_samples_leaf': 1, 'max_features': 'auto', 'max_depth': 1, 'criterion': 'entropy'}
# 0.8401330986143245 {'n_estimators': 639, 'min_samples_split': 5, 'min_samples_leaf': 3, 'max_features': 'auto', 'max_depth': 1, 'criterion': 'entropy'}
# 0.8401588705145343 {'n_estimators': 3792, 'min_samples_split': 2, 'min_samples_leaf': 4, 'max_features': 'sqrt', 'max_depth': 1, 'criterion': 'entropy'}
# 0.8402439500764607 {'n_estimators': 2910, 'min_samples_split': 4, 'min_samples_leaf': 4, 'max_features': 'sqrt', 'max_depth': 1, 'criterion': 'gini'}
# 0.8402775429551083 {'n_estimators': 1307, 'min_samples_split': 3, 'min_samples_leaf': 3, 'max_features': 'auto', 'max_depth': 1, 'criterion': 'entropy'}
# 0.8403065391907211 {'n_estimators': 3119, 'min_samples_split': 4, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'max_depth': 1, 'criterion': 'gini'}
# 0.8403292429648223 {'n_estimators': 2670, 'min_samples_split': 4, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'max_depth': 1, 'criterion': 'entropy'}
# 0.8403579737044846 {'n_estimators': 4512, 'min_samples_split': 2, 'min_samples_leaf': 3, 'max_features': 'auto', 'max_depth': 1, 'criterion': 'gini'}
# 0.8404075571480811 {'n_estimators': 4029, 'min_samples_split': 3, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'max_depth': 1, 'criterion': 'entropy'}
# 0.8404698913199947 {'n_estimators': 3976, 'min_samples_split': 4, 'min_samples_leaf': 3, 'max_features': 'auto', 'max_depth': 1, 'criterion': 'gini'}
# 0.8404995684924718 {'n_estimators': 2243, 'min_samples_split': 4, 'min_samples_leaf': 2, 'max_features': 'auto', 'max_depth': 1, 'criterion': 'gini'}
# 0.8404997869460831 {'n_estimators': 4597, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 'auto', 'max_depth': 1, 'criterion': 'gini'}
# 0.8405625215364837 {'n_estimators': 2726, 'min_samples_split': 3, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'max_depth': 1, 'criterion': 'entropy'}
# 0.8405720274805435 {'n_estimators': 3911, 'min_samples_split': 3, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'max_depth': 1, 'criterion': 'gini'}
# 0.8405996038873833 {'n_estimators': 3268, 'min_samples_split': 4, 'min_samples_leaf': 4, 'max_features': 'log2', 'max_depth': 1, 'criterion': 'gini'}
# 0.
 'min_samples_split': 5, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'max_depth': 2, 'criterion': 'gini'}
# 0.8539246095017208 {'n_estimators': 332, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_features': 'log2', 'max_depth': 2, 'criterion': 'gini'}
# 0.8539469702138769 {'n_estimators': 1326, 'min_samples_split': 2, 'min_samples_leaf': 3, 'max_features': 'log2', 'max_depth': 2, 'criterion': 'gini'}
# 0.853958082959061 {'n_estimators': 1037, 'min_samples_split': 5, 'min_samples_leaf': 1, 'max_features': 'log2', 'max_depth': 2, 'criterion': 'gini'}
# 0.8540324501344401 {'n_estimators': 1787, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'max_depth': 2, 'criterion': 'gini'}
# 0.8540352323157437 {'n_estimators': 745, 'min_samples_split': 3, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'max_depth': 2, 'criterion': 'gini'}
# 0.8540401360107904 {'n_estimators': 1705, 'min_samples_split': 5, 'min_samples_leaf': 3, 'max_features': 'auto', 'max_depth': 2, 'criterion': 'gini'}
# 0.8540590594202098 {'n_estimators': 501, 'min_samples_split': 3, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'max_depth': 2, 'criterion': 'entropy'}
# 0.8540697300112945 {'n_estimators': 470, 'min_samples_split': 4, 'min_samples_leaf': 1, 'max_features': 'auto', 'max_depth': 2, 'criterion': 'entropy'}
# 0.8540987779974707 {'n_estimators': 3836, 'min_samples_split': 3, 'min_samples_leaf': 2, 'max_features': 'log2', 'max_depth': 2, 'criterion': 'gini'}
# 0.8541191834201295 {'n_estimators': 1222, 'min_samples_split': 5, 'min_samples_leaf': 3, 'max_features': 'auto', 'max_depth': 2, 'criterion': 'entropy'}
# 0.8541596094678895 {'n_estimators': 3102, 'min_samples_split': 3, 'min_samples_leaf': 3, 'max_features': 'auto', 'max_depth': 2, 'criterion': 'gini'}
# 0.8541792347418293 {'n_estimators': 863, 'min_samples_split': 4, 'min_samples_leaf': 4, 'max_features': 'log2', 'max_depth': 2, 'criterion': 'gini'}
# 0.8542156929737539 {'n_estimators': 4669, 'min_samples_split': 3, 'min_samples_leaf': 4, 'max_features': 'auto', 'max_depth': 2, 'criterion': 'gini'}
# 0.8542161193872232 {'n_estimators': 4018, 'min_samples_split': 3, 'min_samples_leaf': 2, 'max_features': 'auto', 'max_depth': 2, 'criterion': 'gini'}
# 0.8542570705216543 {'n_estimators': 2978, 'min_samples_split': 3, 'min_samples_leaf': 4, 'max_features': 'sqrt', 'max_depth': 2, 'criterion': 'gini'}
# 0.8542657808157665 {'n_estimators': 1343, 'min_samples_split': 5, 'min_samples_leaf': 2, 'max_features': 'log2', 'max_depth': 2, 'criterion': 'entropy'}
# 0.8542680169228922 {'n_estimators': 4815, 'min_samples_split': 4, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'max_depth': 2, 'criterion': 'gini'}
# 0.8542818804878206 {'n_estimators': 3166, 'min_samples_split': 3, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'max_depth': 2, 'criterion': 'gini'}
# 0.854287345937825 {'n_estimators': 1664, 'min_samples_split': 3, 'min_samples_leaf': 1, 'max_features': 'auto', 'max_depth': 2, 'criterion': 'entropy'}
# 0.8542927435973845 {'n_estimators': 1629, 'min_samples_split': 4, 'min_samples_leaf': 3, 'max_features': 'log2', 'max_depth': 2, 'criterion': 'gini'}
# 0.8542953540681648 {'n_estimators': 2845, 'min_samples_split': 3, 'min_samples_leaf': 3, 'max_features': 'auto', 'max_depth': 2, 'criterion': 'gini'}
# 0.8543093840368897 {'n_estimators': 2369, 'min_samples_split': 4, 'min_samples_leaf': 1, 'max_features': 'log2', 'max_depth': 2, 'criterion': 'gini'}
# 0.8543195295413032 {'n_estimators': 1416, 'min_samples_split': 4, 'min_samples_leaf': 3, 'max_features': 'log2', 'max_depth': 2, 'criterion': 'entropy'}
# 0.8543446931230181 {'n_estimators': 985, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'max_depth': 2, 'criterion': 'gini'}
# 0.8543592534851412 {'n_estimators': 3347, 'min_samples_split': 3, 'min_samples_leaf': 2, 'max_features': 'auto', 'max_depth': 2, 'criterion': 'entropy'}
# 0.8543603767556558 {'n_estimators': 1585, 'min_samples_split': 3, 'min_samples_leaf': 2, 'max_features': 'log2', 'max_depth': 2, 'criterion': 'gini'}
# 0.8543613127545675 {'n_estimators': 1162, 'min_samples_split': 2, 'min_samples_leaf': 4, 'max_features': 'log2', 'max_depth': 2, 'criterion': 'gini'}
# 0.8543651297276856 {'n_estimators': 2348, 'min_samples_split': 5, 'min_samples_leaf': 3, 'max_features': 'auto', 'max_depth': 2, 'criterion': 'entropy'}
# 0.8543742299465312 {'n_estimators': 1741, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 'log2', 'max_depth': 2, 'criterion': 'gini'}
# 0.8543755611170534 {'n_estimators': 2929, 'min_samples_split': 3, 'min_samples_leaf': 4, 'max_features': 'auto', 'max_depth': 2, 'criterion': 'gini'}
# 0.8543866842362902 {'n_estimators': 244, 'min_samples_split': 5, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'max_depth': 2, 'criterion': 'entropy'}
# 0.8543905687604519 {'n_estimators': 4791, 'min_samples_split': 3, 'min_samples_leaf': 1, 'max_features': 'auto', 'max_depth': 2, 'criterion': 'gini'}
# 0.8544011823540966 {'n_estimators': 278, 'min_samples_split': 2, 'min_samples_leaf': 3, 'max_features': 'log2', 'max_depth': 2, 'criterion': 'gini'}
# 0.8544015254758922 {'n_estimators': 1773, 'min_samples_split': 5, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'max_depth': 2, 'criterion': 'gini'}
# 0.8544015878997597 {'n_estimators': 3121, 'min_samples_split': 2, 'min_samples_leaf': 4, 'max_features': 'sqrt', 'max_depth': 2, 'criterion': 'gini'}
# 0.8544045519262388 {'n_estimators': 3549, 'min_samples_split': 2, 'min_samples_leaf': 3, 'max_features': 'log2', 'max_depth': 2, 'criterion': 'gini'}
# 0.8544101474110046 {'n_estimators': 727, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_features': 'sqrt', 'max_depth': 2, 'criterion': 'gini'}
# 0.8544155398835378 {'n_estimators': 3798, 'min_samples_split': 4, 'min_samples_leaf': 4, 'max_features': 'log2', 'max_depth': 2, 'criterion': 'gini'}
# 0.8544272922489259 {'n_estimators': 4370, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_features': 'log2', 'max_depth': 2, 'criterion': 'gini'}
# 0.854432492442381 {'n_estimators': 1807, 'min_samples_split': 4, 'min_samples_leaf': 4, 'max_features': 'sqrt', 'max_depth': 2, 'criterion': 'entropy'}
# 0.8544361533259048 {'n_estimators': 2483, 'min_samples_split': 3, 'min_samples_leaf': 3, 'max_features': 'auto', 'max_depth': 2, 'criterion': 'entropy'}
# 0.8544449206773072 {'n_estimators': 3929, 'min_samples_split': 4, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'max_depth': 2, 'criterion': 'gini'}
# 0.8544808321168501 {'n_estimators': 7, 'min_samples_split': 4, 'min_samples_leaf': 1, 'max_features': 'auto', 'max_depth': None, 'criterion': 'gini'}
# 0.8544912280947875 {'n_estimators': 726, 'min_samples_split': 4, 'min_samples_leaf': 2, 'max_features': 'log2', 'max_depth': 2, 'criterion': 'entropy'}
# 0.8545056689159026 {'n_estimators': 1419, 'min_samples_split': 3, 'min_samples_leaf': 1, 'max_features': 'log2', 'max_depth': 2, 'criterion': 'gini'}
# 0.8545095845622227 {'n_estimators': 4549, 'min_samples_split': 4, 'min_samples_leaf': 3, 'max_features': 'log2', 'max_depth': 2, 'criterion': 'gini'}
# 0.8545165527735721 {'n_estimators': 1814, 'min_samples_split': 3, 'min_samples_leaf': 2, 'max_features': 'log2', 'max_depth': 2, 'criterion': 'entropy'}
# 0.8545236925158943 {'n_estimators': 3479, 'min_samples_split': 3, 'min_samples_leaf': 4, 'max_features': 'sqrt', 'max_depth': 2, 'criterion': 'gini'}
# 0.8545369529493543 {'n_estimators': 1994, 'min_samples_split': 2, 'min_samples_leaf': 4, 'max_features': 'log2', 'max_depth': 2, 'criterion': 'gini'}
# 0.8545447271847043 {'n_estimators': 1895, 'min_samples_split': 2, 'min_samples_leaf': 3, 'max_features': 'auto', 'max_depth': 2, 'criterion': 'entropy'}
# 0.8545583932236778 {'n_estimators': 884, 'min_samples_split': 2, 'min_samples_leaf': 4, 'max_features': 'log2', 'max_depth': 2, 'criterion': 'entropy'}
# 0.8545768536710417 {'n_estimators': 3965, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 'sqrt', 'max_depth': 2, 'criterion': 'gini'}
# 0.8545872696190309 {'n_estimators': 2186, 'min_samples_split': 5, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'max_depth': 2, 'criterion': 'gini'}
# 0.8545894432424389 {'n_estimators': 4870, 'min_samples_split': 3, 'min_samples_leaf': 4, 'max_features': 'log2', 'max_depth': 2, 'criterion': 'gini'}
# 0.8546260626911336 {'n_estimators': 2854, 'min_samples_split': 5, 'min_samples_leaf': 1, 'max_features': 'auto', 'max_depth': 2, 'criterion': 'entropy'}
# 0.8546269311390015 {'n_estimators': 561, 'min_samples_split': 3, 'min_samples_leaf': 3, 'max_features': 'auto', 'max_depth': 2, 'criterion': 'gini'}
# 0.854627877511966 {'n_estimators': 4721, 'min_samples_split': 4, 'min_samples_leaf': 2, 'max_features': 'log2', 'max_depth': 2, 'criterion': 'gini'}
# 0.8546375498598225 {'n_estimators': 822, 'min_samples_split': 5, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'max_depth': 2, 'criterion': 'gini'}
# 0.8546420479493556 {'n_estimators': 3330, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_features': 'log2', 'max_depth': 2, 'criterion': 'gini'}
# 0.8546467541782977 {'n_estimators': 1483, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 'auto', 'max_depth': 2, 'criterion': 'entropy'}
# 0.8546522818726187 {'n_estimators': 1348, 'min_samples_split': 4, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'max_depth': 2, 'criterion': 'gini'}
# 0.8546584025039062 {'n_estimators': 4101, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 'log2', 'max_depth': 2, 'criterion': 'entropy'}
# 0.8546763169967929 {'n_estimators': 3332, 'min_samples_split': 3, 'min_samples_leaf': 3, 'max_features': 'auto', 'max_depth': 2, 'criterion': 'entropy'}
# 0.8546812622479012 {'n_estimators': 2911, 'min_samples_split': 5, 'min_samples_leaf': 3, 'max_features': 'log2', 'max_depth': 2, 'criterion': 'gini'}
# 0.8546879235867894 {'n_estimators': 94, 'min_samples_split': 2, 'min_samples_leaf': 4, 'max_features': 'auto', 'max_depth': 2, 'criterion': 'gini'}
# 0.854692764977669 {'n_estimators': 3604, 'min_samples_split': 5, 'min_samples_leaf': 2, 'max_features': 'auto', 'max_depth': 2, 'criterion': 'entropy'}
# 0.8546950635086623 {'n_estimators': 1179, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_features': 'log2', 'max_depth': 2, 'criterion': 'gini'}
# 0.8547064362036688 {'n_estimators': 1015, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_features': 'auto', 'max_depth': 2, 'criterion': 'entropy'}
# 0.854718994533207 {'n_estimators': 2921, 'min_samples_split': 2, 'min_samples_leaf': 3, 'max_features': 'auto', 'max_depth': 2, 'criterion': 'gini'}
# 0.8547194781835176 {'n_estimators': 2717, 'min_samples_split': 3, 'min_samples_leaf': 2, 'max_features': 'auto', 'max_depth': 2, 'criterion': 'entropy'}
# ...
# 0.8717129008792447 {'n_estimators': 3676, 'min_samples_split': 3, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'max_depth': None, 'criterion': 'entropy'}
# 0.8717195361633004 {'n_estimators': 3276, 'min_samples_split': 5, 'min_samples_leaf': 2, 'max_features': 'auto', 'max_depth': None, 'criterion': 'gini'}
# 0.8717379864161625 {'n_estimators': 1781, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_features': 'log2', 'max_depth': None, 'criterion': 'gini'}
# 0.871767939219242 {'n_estimators': 2976, 'min_samples_split': 5, 'min_samples_leaf': 2, 'max_features': 'log2', 'max_depth': None, 'criterion': 'gini'}
# 0.8717929623921425 {'n_estimators': 1178, 'min_samples_split': 5, 'min_samples_leaf': 2, 'max_features': 'auto', 'max_depth': None, 'criterion': 'entropy'}
# 0.8718232063869036 {'n_estimators': 3036, 'min_samples_split': 5, 'min_samples_leaf': 2, 'max_features': 'log2', 'max_depth': None, 'criterion': 'entropy'}
# 0.8718390359146332 {'n_estimators': 608, 'min_samples_split': 2, 'min_samples_leaf': 4, 'max_features': 'sqrt', 'max_depth': None, 'criterion': 'gini'}
# 0.8718720670981732 {'n_estimators': 2063, 'min_samples_split': 5, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'max_depth': None, 'criterion': 'entropy'}
# 0.8718726705887433 {'n_estimators': 756, 'min_samples_split': 5, 'min_samples_leaf': 1, 'max_features': 'auto', 'max_depth': 9, 'criterion': 'entropy'}
# 0.8719498613219367 {'n_estimators': 2948, 'min_samples_split': 4, 'min_samples_leaf': 2, 'max_features': 'auto', 'max_depth': None, 'criterion': 'entropy'}
# 0.8719539173770712 {'n_estimators': 4480, 'min_samples_split': 5, 'min_samples_leaf': 2, 'max_features': 'auto', 'max_depth': None, 'criterion': 'entropy'}
# 0.8720048164301106 {'n_estimators': 2571, 'min_samples_split': 3, 'min_samples_leaf': 2, 'max_features': 'log2', 'max_depth': None, 'criterion': 'entropy'}
# 0.872036277301262 {'n_estimators': 4510, 'min_samples_split': 5, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'max_depth': None, 'criterion': 'entropy'}
# 0.8720880811712045 {'n_estimators': 4472, 'min_samples_split': 5, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'max_depth': None, 'criterion': 'entropy'}
# 0.8721894321157087 {'n_estimators': 2503, 'min_samples_split': 4, 'min_samples_leaf': 2, 'max_features': 'auto', 'max_depth': None, 'criterion': 'entropy'}
# 0.8722105345749634 {'n_estimators': 2980, 'min_samples_split': 2, 'min_samples_leaf': 4, 'max_features': 'sqrt', 'max_depth': None, 'criterion': 'gini'}
# 0.8722473409960094 {'n_estimators': 254, 'min_samples_split': 5, 'min_samples_leaf': 2, 'max_features': 'auto', 'max_depth': None, 'criterion': 'entropy'}
# 0.8722585629081486 {'n_estimators': 136, 'min_samples_split': 3, 'min_samples_leaf': 3, 'max_features': 'auto', 'max_depth': None, 'criterion': 'entropy'}
# 0.8723522383503551 {'n_estimators': 2153, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_features': 'auto', 'max_depth': None, 'criterion': 'entropy'}
# 0.8725310820725893 {'n_estimators': 1191, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_features': 'auto', 'max_depth': None, 'criterion': 'gini'}
# 0.8725672957362195 {'n_estimators': 4288, 'min_samples_split': 3, 'min_samples_leaf': 3, 'max_features': 'log2', 'max_depth': None, 'criterion': 'entropy'}
# 0.8726097707392033 {'n_estimators': 1567, 'min_samples_split': 2, 'min_samples_leaf': 4, 'max_features': 'log2', 'max_depth': None, 'criterion': 'gini'}
# 0.8726151164087984 {'n_estimators': 1841, 'min_samples_split': 4, 'min_samples_leaf': 4, 'max_features': 'auto', 'max_depth': None, 'criterion': 'gini'}
# 0.8726374355050427 {'n_estimators': 4683, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_features': 'log2', 'max_depth': None, 'criterion': 'gini'}
# 0.872661564235093 {'n_estimators': 4856, 'min_samples_split': 2, 'min_samples_leaf': 4, 'max_features': 'auto', 'max_depth': None, 'criterion': 'gini'}
# 0.872691121866562 {'n_estimators': 3089, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_features': 'log2', 'max_depth': None, 'criterion': 'gini'}
# 0.8727504969596217 {'n_estimators': 2936, 'min_samples_split': 5, 'min_samples_leaf': 2, 'max_features': 'log2', 'max_depth': None, 'criterion': 'entropy'}
# 0.872755749322592 {'n_estimators': 470, 'min_samples_split': 4, 'min_samples_leaf': 4, 'max_features': 'auto', 'max_depth': None, 'criterion': 'gini'}
# 0.8727795658136039 {'n_estimators': 1453, 'min_samples_split': 5, 'min_samples_leaf': 3, 'max_features': 'log2', 'max_depth': None, 'criterion': 'entropy'}
# 0.8727974440571563 {'n_estimators': 1060, 'min_samples_split': 5, 'min_samples_leaf': 3, 'max_features': 'auto', 'max_depth': None, 'criterion': 'entropy'}
# 0.8727979120865373 {'n_estimators': 3078, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_features': 'sqrt', 'max_depth': None, 'criterion': 'gini'}
# 0.872856413604553 {'n_estimators': 1958, 'min_samples_split': 2, 'min_samples_leaf': 3, 'max_features': 'log2', 'max_depth': None, 'criterion': 'gini'}
# 0.872874905473327 {'n_estimators': 2074, 'min_samples_split': 2, 'min_samples_leaf': 4, 'max_features': 'sqrt', 'max_depth': None, 'criterion': 'entropy'}
# 0.8729057527192564 {'n_estimators': 4738, 'min_samples_split': 4, 'min_samples_leaf': 4, 'max_features': 'sqrt', 'max_depth': None, 'criterion': 'gini'}
# 0.8729316807090605 {'n_estimators': 4316, 'min_samples_split': 2, 'min_samples_leaf': 4, 'max_features': 'auto', 'max_depth': None, 'criterion': 'gini'}
# 0.8729353725351917 {'n_estimators': 383, 'min_samples_split': 2, 'min_samples_leaf': 3, 'max_features': 'auto', 'max_depth': None, 'criterion': 'entropy'}
# 0.8729656583254151 {'n_estimators': 287, 'min_samples_split': 4, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'max_depth': None, 'criterion': 'entropy'}
# 0.8729702865694103 {'n_estimators': 526, 'min_samples_split': 2, 'min_samples_leaf': 4, 'max_features': 'auto', 'max_depth': None, 'criterion': 'gini'}
# 0.872977088496664 {'n_estimators': 3169, 'min_samples_split': 3, 'min_samples_leaf': 4, 'max_features': 'sqrt', 'max_depth': None, 'criterion': 'entropy'}
# 0.8729796261096737 {'n_estimators': 1589, 'min_samples_split': 3, 'min_samples_leaf': 4, 'max_features': 'log2', 'max_depth': None, 'criterion': 'gini'}
# 0.8730122309994449 {'n_estimators': 4073, 'min_samples_split': 3, 'min_samples_leaf': 4, 'max_features': 'auto', 'max_depth': None, 'criterion': 'entropy'}
# 0.8730356524983975 {'n_estimators': 4708, 'min_samples_split': 3, 'min_samples_leaf': 4, 'max_features': 'log2', 'max_depth': None, 'criterion': 'gini'}
# 0.8730455013847019 {'n_estimators': 4717, 'min_samples_split': 3, 'min_samples_leaf': 3, 'max_features': 'auto', 'max_depth': None, 'criterion': 'entropy'}
# 0.8730743412913194 {'n_estimators': 802, 'min_samples_split': 4, 'min_samples_leaf': 3, 'max_features': 'auto', 'max_depth': None, 'criterion': 'gini'}
# 0.8730973572446088 {'n_estimators': 3008, 'min_samples_split': 4, 'min_samples_leaf': 3, 'max_features': 'log2', 'max_depth': None, 'criterion': 'gini'}
# 0.8730985325050878 {'n_estimators': 2548, 'min_samples_split': 5, 'min_samples_leaf': 3, 'max_features': 'log2', 'max_depth': None, 'criterion': 'entropy'}
# 0.873113821145666 {'n_estimators': 2165, 'min_samples_split': 4, 'min_samples_leaf': 4, 'max_features': 'log2', 'max_depth': None, 'criterion': 'entropy'}
# 0.8731236907800758 {'n_estimators': 1026, 'min_samples_split': 3, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'max_depth': None, 'criterion': 'gini'}
# 0.8731243772630684 {'n_estimators': 1547, 'min_samples_split': 4, 'min_samples_leaf': 3, 'max_features': 'log2', 'max_depth': None, 'criterion': 'entropy'}
# 0.8731244812429971 {'n_estimators': 1202, 'min_samples_split': 4, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'max_depth': None, 'criterion': 'entropy'}
# 0.8731505339608356 {'n_estimators': 2104, 'min_samples_split': 4, 'min_samples_leaf': 3, 'max_features': 'auto', 'max_depth': None, 'criterion': 'entropy'}
# 0.8731768571222497 {'n_estimators': 2409, 'min_samples_split': 4, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'max_depth': None, 'criterion': 'gini'}
# 0.873177855545029 {'n_estimators': 4153, 'min_samples_split': 4, 'min_samples_leaf': 3, 'max_features': 'log2', 'max_depth': None, 'criterion': 'entropy'}
# 0.8731783548162689 {'n_estimators': 1997, 'min_samples_split': 3, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'max_depth': None, 'criterion': 'entropy'}
# 0.8731795611989063 {'n_estimators': 4239, 'min_samples_split': 2, 'min_samples_leaf': 3, 'max_features': 'log2', 'max_depth': None, 'criterion': 'entropy'}
# 0.8731806739756673 {'n_estimators': 3048, 'min_samples_split': 3, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'max_depth': None, 'criterion': 'entropy'}
# 0.8731835134536625 {'n_estimators': 3009, 'min_samples_split': 4, 'min_samples_leaf': 4, 'max_features': 'auto', 'max_depth': None, 'criterion': 'gini'}
# 0.8731956610505113 {'n_estimators': 4070, 'min_samples_split': 4, 'min_samples_leaf': 4, 'max_features': 'auto', 'max_depth': None, 'criterion': 'entropy'}
# 0.8732965128434759 {'n_estimators': 1162, 'min_samples_split': 2, 'min_samples_leaf': 4, 'max_features': 'sqrt', 'max_depth': None, 'criterion': 'entropy'}
# 0.8733014528477073 {'n_estimators': 1638, 'min_samples_split': 4, 'min_samples_leaf': 4, 'max_features': 'auto', 'max_depth': None, 'criterion': 'entropy'}
# 0.8733274744433874 {'n_estimators': 2507, 'min_samples_split': 2, 'min_samples_leaf': 4, 'max_features': 'auto', 'max_depth': None, 'criterion': 'entropy'}
# 0.8733640832786279 {'n_estimators': 4997, 'min_samples_split': 2, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'max_depth': None, 'criterion': 'entropy'}
# 0.8733804743219143 {'n_estimators': 3988, 'min_samples_split': 4, 'min_samples_leaf': 4, 'max_features': 'log2', 'max_depth': None, 'criterion': 'gini'}
# 0.8733829079549948 {'n_estimators': 1747, 'min_samples_split': 4, 'min_samples_leaf': 4, 'max_features': 'sqrt', 'max_depth': None, 'criterion': 'entropy'}
# 0.873393744890026 {'n_estimators': 2778, 'min_samples_split': 2, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'max_depth': None, 'criterion': 'entropy'}
# 0.8733947640609109 {'n_estimators': 4768, 'min_samples_split': 2, 'min_samples_leaf': 3, 'max_features': 'auto', 'max_depth': None, 'criterion': 'entropy'}
# 0.8734172599948546 {'n_estimators': 3493, 'min_samples_split': 2, 'min_samples_leaf': 3, 'max_features': 'log2', 'max_depth': None, 'criterion': 'entropy'}
# 0.8734729223341264 {'n_estimators': 4390, 'min_samples_split': 3, 'min_samples_leaf': 3, 'max_features': 'log2', 'max_depth': None, 'criterion': 'entropy'}
# 0.8734991935055761 {'n_estimators': 3420, 'min_samples_split': 2, 'min_samples_leaf': 3, 'max_features': 'log2', 'max_depth': None, 'criterion': 'entropy'}
# 0.8735223341869001 {'n_estimators': 734, 'min_samples_split': 4, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'max_depth': None, 'criterion': 'gini'}
# 0.873523582185449 {'n_estimators': 2811, 'min_samples_split': 4, 'min_samples_leaf': 3, 'max_features': 'auto', 'max_depth': None, 'criterion': 'gini'}
# 0.8735340762380854 {'n_estimators': 459, 'min_samples_split': 2, 'min_samples_leaf': 3, 'max_features': 'log2', 'max_depth': None, 'criterion': 'gini'}
# 0.8735397236529657 {'n_estimators': 1628, 'min_samples_split': 2, 'min_samples_leaf': 4, 'max_features': 'sqrt', 'max_depth': None, 'criterion': 'gini'}
# 0.873551891818369 {'n_estimators': 1617, 'min_samples_split': 2, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'max_depth': None, 'criterion': 'entropy'}
# 0.8735661820361678 {'n_estimators': 1259, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_features': 'log2', 'max_depth': None, 'criterion': 'entropy'}
# 0.8735754796612677 {'n_estimators': 2861, 'min_samples_split': 3, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'max_depth': None, 'criterion': 'gini'}
# 0.8735943668213527 {'n_estimators': 4362, 'min_samples_split': 4, 'min_samples_leaf': 4, 'max_features': 'log2', 'max_depth': None, 'criterion': 'entropy'}
# 0.8736024164479036 {'n_estimators': 4581, 'min_samples_split': 3, 'min_samples_leaf': 3, 'max_features': 'log2', 'max_depth': None, 'criterion': 'gini'}
# 0.8736203571751737 {'n_estimators': 3100, 'min_samples_split': 4, 'min_samples_leaf': 4, 'max_features': 'sqrt', 'max_depth': None, 'criterion': 'entropy'}
# 0.8736361132466298 {'n_estimators': 357, 'min_samples_split': 3, 'min_samples_leaf': 3, 'max_features': 'auto', 'max_depth': None, 'criterion': 'gini'}
# 0.873647481173562 {'n_estimators': 424, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_features': 'log2', 'max_depth': None, 'criterion': 'entropy'}
# 0.8736590252199903 {'n_estimators': 2928, 'min_samples_split': 2, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'max_depth': None, 'criterion': 'gini'}
# 0.8736754058892239 {'n_estimators': 4177, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_features': 'sqrt', 'max_depth': None, 'criterion': 'entropy'}
# 0.8736754371310828 {'n_estimators': 4704, 'min_samples_split': 3, 'min_samples_leaf': 4, 'max_features': 'auto', 'max_depth': None, 'criterion': 'entropy'}
# 0.8736758323026932 {'n_estimators': 3524, 'min_samples_split': 3, 'min_samples_leaf': 4, 'max_features': 'log2', 'max_depth': None, 'criterion': 'gini'}
# 0.8736917137006869 {'n_estimators': 459, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_features': 'auto', 'max_depth': None, 'criterion': 'entropy'}
# 0.8737085203045873 {'n_estimators': 1935, 'min_samples_split': 4, 'min_samples_leaf': 3, 'max_features': 'log2', 'max_depth': None, 'criterion': 'entropy'}
# 0.8737133252067312 {'n_estimators': 3724, 'min_samples_split': 4, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'max_depth': None, 'criterion': 'entropy'}
# 0.8737336994473813 {'n_estimators': 1215, 'min_samples_split': 4, 'min_samples_leaf': 3, 'max_features': 'log2', 'max_depth': None, 'criterion': 'entropy'}
# 0.8737500385007034 {'n_estimators': 1166, 'min_samples_split': 3, 'min_samples_leaf': 4, 'max_features': 'auto', 'max_depth': None, 'criterion': 'gini'}
# 0.8737879265763518 {'n_estimators': 4772, 'min_samples_split': 2, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'max_depth': None, 'criterion': 'gini'}
# 0.8738082696948437 {'n_estimators': 2170, 'min_samples_split': 3, 'min_samples_leaf': 4, 'max_features': 'sqrt', 'max_depth': None, 'criterion': 'entropy'}
# 0.8738449305200489 {'n_estimators': 4015, 'min_samples_split': 5, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'max_depth': None, 'criterion': 'gini'}
# 0.8738679775954967 {'n_estimators': 2430, 'min_samples_split': 2, 'min_samples_leaf': 3, 'max_features': 'auto', 'max_depth': None, 'criterion': 'gini'}
# 0.8738955696232659 {'n_estimators': 1366, 'min_samples_split': 4, 'min_samples_leaf': 3, 'max_features': 'log2', 'max_depth': None, 'criterion': 'gini'}
# 0.873935943800762 {'n_estimators': 808, 'min_samples_split': 3, 'min_samples_leaf': 4, 'max_features': 'sqrt', 'max_depth': None, 'criterion': 'entropy'}
# 0.8739777530090085 {'n_estimators': 314, 'min_samples_split': 2, 'min_samples_leaf': 4, 'max_features': 'sqrt', 'max_depth': None, 'criterion': 'entropy'}
# 0.8739942686007786 {'n_estimators': 382, 'min_samples_split': 4, 'min_samples_leaf': 4, 'max_features': 'log2', 'max_depth': None, 'criterion': 'entropy'}
# 0.8740503885953788 {'n_estimators': 1193, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_features': 'sqrt', 'max_depth': None, 'criterion': 'entropy'}
# 0.8740982923800802 {'n_estimators': 3228, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_features': 'log2', 'max_depth': None, 'criterion': 'entropy'}
# 0.8741258531659906 {'n_estimators': 128, 'min_samples_split': 2, 'min_samples_leaf': 4, 'max_features': 'auto', 'max_depth': None, 'criterion': 'entropy'}
# 0.8741877243758489 {'n_estimators': 275, 'min_samples_split': 3, 'min_samples_leaf': 3, 'max_features': 'auto', 'max_depth': None, 'criterion': 'entropy'}
# 0.8742176979270336 {'n_estimators': 3728, 'min_samples_split': 5, 'min_samples_leaf': 3, 'max_features': 'sqrt', 'max_depth': None, 'criterion': 'gini'}

# %%
r.best_estimator_
forest_best = r.best_estimator_
scores = r.cv_results_

# %%
parameters = {
 "learning_rate": uniform(0.01, 2),
 "n_estimators": list(range(1, 1000)),      
    } 

model = AdaBoostClassifier()
randomsearch = RandomizedSearchCV(model,
                                  param_distributions=parameters,
                                  n_iter=100,
                                  cv=5,
                                  random_state=1,
                                  scoring=scoring,
                                  return_train_score=True,
                                  refit='Accuracy',
                                  verbose=0)

r = randomsearch.fit(data,y)
max(r.cv_results_['mean_test_AUC'])
# Out:
# 0.8592548956733103

# %%
r.best_estimator_
ada_best = r.best_estimator_
# Out:
# AdaBoostClassifier(algorithm='SAMME.R', base_estimator=None,
#           learning_rate=0.6069905895060894, n_estimators=739,
#           random_state=None)

# %%
parameters = {
    "Cs": list(range(1,100)),
    "penalty": ["l2"],
    "solver": ["newton-cg", "lbfgs", "liblinear", "sag", "saga"],      
    } 

model = LogisticRegressionCV(max_iter=1000)
randomsearch = RandomizedSearchCV(model,
                                  param_distributions=parameters,
                                  n_iter=100,
                                  cv=5,
                                  random_state=1,
                                  scoring=scoring,
                                  return_train_score=True,
                                  refit='Accuracy',
                                  verbose=0)

r = randomsearch.fit(data,y)
max(r.cv_results_['mean_test_AUC'])
# Out:
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/sag.py:334: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/sag.py:334: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/sag.py:334: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/sag.py:334: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/sag.py:334: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/sag.py:334: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/sag.py:334: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/sag.py:334: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/sag.py:334: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
# ...
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/sag.py:334: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/sag.py:334: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/sag.py:334: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/sag.py:334: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/sag.py:334: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/sag.py:334: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/sag.py:334: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/sag.py:334: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   "the coef_ did not converge", ConvergenceWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# 0.8517743794830757

# %%
r.best_estimator_
logistic_best = r.best_estimator_
# Out:
# LogisticRegressionCV(Cs=93, class_weight=None, cv='warn', dual=False,
#            fit_intercept=True, intercept_scaling=1.0, max_iter=1000,
#            multi_class='warn', n_jobs=None, penalty='l2',
#            random_state=None, refit=True, scoring=None, solver='saga',
#            tol=0.0001, verbose=0)

# %%
parameters = {
    "weights": ["uniform", "distance"],
    "n_neighbors": list(range(1,10)),    
    } 

model = KNeighborsClassifier()
randomsearch = RandomizedSearchCV(model,
                                  param_distributions=parameters,
                                  n_iter=20,
                                  cv=4,
                                  random_state=1,
                                  scoring=scoring,
                                  return_train_score=True,
                                  refit='Accuracy')

r = randomsearch.fit(data,y)
max(r.cv_results_['mean_test_AUC'])
# Out:
# /home/dawpalu/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_search.py:271: UserWarning: The total space of parameters 18 is smaller than n_iter=20. Running 18 iterations. For exhaustive searches, use GridSearchCV.
#   % (grid_size, self.n_iter, grid_size), UserWarning)
# 0.8538840457675447

# %%
r.best_estimator_
knn_best = r.best_estimator_

# %% [markdown]
# ## Fine-Tune the System
# ***
# ### You will want to use as much data as possible for this step, especially as you move toward the end of fine-tuning.As always, automate what you can.
#
# 1 Fine-tune the hyperparameters using cross-validation
#
# 2. Treat your data transformation choices as hyperparameters, especially when you are not sure about them (e.g., if you’re not sure whether to replace missing values with zeros or with the median value, or to just drop the rows).
#
# 3. Unless there are very few hyperparameter values to explore, prefer random search over grid search. If training is very long, you may prefer a Bayesian optimization approach (e.g., using Gaussian process priors, as described by Jasper Snoek et al.).
#
# 4. Try Ensemble methods. Combining your best models will often produce better performance than running them individually.
#
# 5. Once you are confident about your final model, measure its performance on the test set to estimate the generalization error.

# %%
#After some trials this is the model I decided to use. It performs pretty well on kaggle competition.
# It has  0.78708 accuracy  and places me in the top 13%, witch is not too bad as it is the most known competition. 

random_forest = RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
            max_depth=6, max_features='sqrt', max_leaf_nodes=None,
            min_impurity_decrease=0.0, min_impurity_split=None,
            min_samples_leaf=1, min_samples_split=2,
            min_weight_fraction_leaf=0.0, n_estimators=3120, n_jobs=None,
            oob_score=False, random_state=None, verbose=0,
            warm_start=False)
random_forest.fit(data, y)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=6, max_features='sqrt', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=3120, n_jobs=None,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
final_model = forest_best
test = pd.read_csv('test_data/test.csv')

test['transformed_cabin'] = test['Cabin'].fillna('N').map(lambda x: x[0])
indexes = test['PassengerId']

cols_to_drop=["PassengerId", "Name", "Cabin","Ticket","transformed_cabin"]
test.drop(cols_to_drop, axis=1, inplace=True)

test = full_pipeline.transform(test)

res = final_model.predict(test)

df = pd.DataFrame(res,columns=["Survived"])
df['PassengerId'] = indexes
df.to_csv("result.csv", index=False)
